# %%
import json
import os
import glob
def extract_schema_info(schema_file):
    """
    Parse the schema.json file and extract all table names and column names.
    :param schema_file: Path to the JSON file
    :return: A dictionary containing table names as keys and column names as values
    """
    with open(schema_file, "r", encoding="utf-8") as file:
        schema = json.load(file)

    schema_info = {}
    print(schema.get("wikidata_topic_item_id"))
    print(schema.get("wikidata_topic_item_label"))
    for table in schema.get("tables", []):
        table_name = table.get("table_name", "UNKNOWN_TABLE")  # Get table name
        column_names = [col["column_name"] for col in table.get("columns", [])]  # Extract column names
        schema_info[table_name] = column_names  # Store in dictionary

    return schema_info

def display_schema_info(schema_info):
    """
    Print the extracted schema information in a structured format.
    """
    for table, columns in schema_info.items():
        print(f"    ├── 📂 Table: {table.lower()}")
        # for col in columns:
            # print(f"    |    ├── {col.lower()}")
        print("")  # Add a blank line for readability

def print_schema(dbs_name):
    # Example usage
    print(f"{dbs_name.lower()}")

    schema_dir = "../../data/schema"
    pattern = os.path.join(schema_dir, f"{dbs_name}*.json")
    matched_files = glob.glob(pattern)

    if not matched_files:
        print(f"⚠️ No schema files found with prefix '{dbs_name}'")
        return

    schema_path = matched_files[0]
    print(f"📂 Matched schema file: {os.path.basename(schema_path)}")

    schema_info = extract_schema_info(schema_path)
    display_schema_info(schema_info)

# %%
print_schema("24205")
print_schema("66305")
# Out:
# 24205
# 📂 Matched schema file: 24205_FynRegulationMolecularBiologyDb.json
# Q18024903
# FYN
#     ├── 📂 Table: micrornaregulationentries
#
#     ├── 📂 Table: generegulationdetails
#
#     ├── 📂 Table: humanchromosome12details
#
# 66305
# 📂 Matched schema file: 66305_Trypanosoma_Cruzi_Orthologs_Db_663.json
# Q62256153
# TcCLB.507959.140
#     ├── 📂 Table: gene_orthologs
#
#     ├── 📂 Table: orthology

# %%
# 73720_93351
print_schema("73720")
print_schema("93351")
# Out:
# 73720
# 📂 Matched schema file: 73720_SOYUZ_TM_MISSIONS_DATABASE.json
# Q2705481
# Soyuz-TM
#     ├── 📂 Table: soyuz_tm_mission_details
#     |    ├── mission_label
#     |    ├── mission_description
#     |    ├── cospar_id
#     |    ├── spacecraft_catalog_number
#     |    ├── launch_date_utc
#     |    ├── launch_vehicle
#     |    ├── spacecraft_instance
#     |    ├── mission_patch_image
#     |    ├── program_affiliation
#     |    ├── preceding_mission
#     |    ├── succeeding_mission
#     |    ├── orbit_type
#     |    ├── freebase_id
#     |    ├── crew_members
#     |    ├── spacecraft_model
#     |    ├── orbits_completed
#     |    ├── landing_date_utc
#     |    ├── orbital_inclination_degrees
#     |    ├── orbital_period_minutes
#     |    ├── apoapsis_km
#     |    ├── periapsis_km
#     |    ├── spacecraft_mass_kg
#     |    ├── mission_duration_seconds
#     |    ├── landing_location
#     |    ├── mission_operator
#     |    ├── launch_site
#     |    ├── mission_logo_image
#     |    ├── launch_country
#     |    ├── notable_event
#     |    ├── orbit_decay_date_utc
#     |    ├── commons_category
#     |    ├── mission_image
#     |    ├── wolfram_entity_code
#
#     ├── 📂 Table: soyuz_tm_crew_members
#     |    ├── full_name
#     |    ├── biography
#     |    ├── commons_category
#     |    ├── entity_type
#     |    ├── birth_date
#     |    ├── profession
#     |    ├── birth_place
#     |    ├── education
#     |    ├── mission_name
#     |    ├── freebase_id
#     |    ├── citizenship
#     |    ├── honors_awarded
#     |    ├── first_name
#     |    ├── profile_image
#     |    ├── military_service
#     |    ├── space_duration
#     |    ├── warheroesru_id
#     |    ├── languages
#     |    ├── rank
#     |    ├── national_allegiance
#     |    ├── gender
#     |    ├── prabook_id
#     |    ├── great_russian_encyclopedia_online_id_old_version
#     |    ├── political_affiliation
#     |    ├── visuotine_lietuviu_enciklopedija_id
#     |    ├── biografijaru_id
#
#     ├── 📂 Table: spaceflight
#     |    ├── mission_label
#     |    ├── mission_description
#     |    ├── cospar_id
#     |    ├── satellite_catalog_number
#     |    ├── launch_utc_date
#     |    ├── launch_vehicle
#     |    ├── spacecraft_instance
#     |    ├── orbit_type
#     |    ├── freebase_id
#     |    ├── crew_members
#     |    ├── vessel_name
#     |    ├── orbits_completed
#     |    ├── landing_utc_date
#     |    ├── orbital_inclination_degrees
#     |    ├── orbital_period_minutes
#     |    ├── apoapsis_km
#     |    ├── periapsis_km
#     |    ├── spacecraft_mass_kg
#     |    ├── mission_duration_seconds
#     |    ├── landing_location
#     |    ├── program_part
#     |    ├── previous_mission
#     |    ├── next_mission
#     |    ├── operating_agency
#     |    ├── launch_site
#     |    ├── launch_country
#     |    ├── notable_event
#     |    ├── wolfram_entity_code
#     |    ├── mission_patch_image
#     |    ├── mission_logo_image
#     |    ├── commons_category
#     |    ├── orbit_decay_utc_date
#     |    ├── crew_portrait_image
#
# 93351
# 📂 Matched schema file: 93351_SOYUZ_TM_MISSIONS_DATABASE_1.json
# Q2705481
# Soyuz-TM
#     ├── 📂 Table: soyuz_tm_mission_details
#     |    ├── mission_label
#     |    ├── mission_description
#     |    ├── cospar_id
#     |    ├── satellite_catalog_number
#     |    ├── launch_date_utc
#     |    ├── launch_vehicle
#     |    ├── spacecraft_type
#     |    ├── mission_patch_image
#     |    ├── program_affiliation
#     |    ├── preceding_mission
#     |    ├── succeeding_mission
#     |    ├── orbit_type
#     |    ├── freebase_id
#     |    ├── crew_members
#     |    ├── vessel_type
#     |    ├── orbits_completed
#     |    ├── landing_date_utc
#     |    ├── orbital_inclination_degrees
#     |    ├── orbital_period_minutes
#     |    ├── apoapsis_km
#     |    ├── periapsis_km
#     |    ├── spacecraft_mass_kg
#     |    ├── mission_duration_seconds
#     |    ├── landing_location
#     |    ├── mission_operator
#     |    ├── launch_site
#     |    ├── mission_logo_image
#     |    ├── launch_country
#     |    ├── notable_event
#     |    ├── orbit_decay_date_utc
#     |    ├── commons_category
#     |    ├── mission_image
#     |    ├── wolfram_entity_code
#
#     ├── 📂 Table: soyuz_tm_crew_profiles
#     |    ├── full_name
#     |    ├── biography
#     |    ├── commons_category
#     |    ├── entity_type
#     |    ├── birth_date
#     |    ├── profession
#     |    ├── birth_place
#     |    ├── education
#     |    ├── mission_name
#     |    ├── freebase_id
#     |    ├── nationality
#     |    ├── honors
#     |    ├── first_name
#     |    ├── profile_image
#     |    ├── military_service
#     |    ├── space_duration
#     |    ├── warheroesru_id
#     |    ├── languages
#     |    ├── military_rank
#     |    ├── political_affiliation
#     |    ├── gender
#     |    ├── prabook_id
#     |    ├── great_russian_encyclopedia_online_id_old_version
#     |    ├── political_party_membership
#     |    ├── visuotine_lietuviu_enciklopedija_id
#     |    ├── biografijaru_id
#
#     ├── 📂 Table: spaceflight
#     |    ├── mission_label
#     |    ├── mission_description
#     |    ├── cospar_id
#     |    ├── satellite_catalog_number
#     |    ├── launch_utc_date
#     |    ├── launch_vehicle
#     |    ├── spacecraft_model
#     |    ├── orbit_type
#     |    ├── freebase_id
#     |    ├── crew_members
#     |    ├── vessel_name
#     |    ├── orbits_completed
#     |    ├── landing_utc_date
#     |    ├── orbital_inclination_degrees
#     |    ├── orbital_period_minutes
#     |    ├── apoapsis_km
#     |    ├── periapsis_km
#     |    ├── spacecraft_mass_kg
#     |    ├── mission_duration_seconds
#     |    ├── landing_location
#     |    ├── program_part
#     |    ├── previous_mission
#     |    ├── next_mission
#     |    ├── operating_agency
#     |    ├── launch_site
#     |    ├── launch_country
#     |    ├── notable_event
#     |    ├── wolfram_entity_code
#     |    ├── mission_patch_image
#     |    ├── mission_logo_image
#     |    ├── commons_category
#     |    ├── orbit_decay_date
#     |    ├── mission_image

# %%
import sys
sys.path.append("..")
from model.WKDataset import WKDataset
SAMPLE_SIZE = 1000
INPUT_TXT = "/hpctmp/e1351271/wkdbs/out/sampled_ids_1000.txt"
dataset = WKDataset(schema_dir="../../data/schema", csv_base_dir="../../data/unzip")
sampled_ids = dataset.save_sampled_ids(INPUT_TXT, k=SAMPLE_SIZE, seed=42)

# %%
import os
import io
import sys
def capture_print_schema(db_id):
    buffer = io.StringIO()
    sys_stdout = sys.stdout
    sys.stdout = buffer
    try:
        print_schema(db_id)
    finally:
        sys.stdout = sys_stdout
    return buffer.getvalue()

directory = "/hpctmp/e1351271/wkdbs/out/qid_pairs_max_similarity"

similarity_data = []

for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory, filename)
        with open(file_path, "r") as f:
            db_pair = None
            max_sim = None
            for line in f:
                if "<-->" in line:
                    db_pair = [s.strip() for s in line.strip().split("<-->")]
                elif line.startswith("Max similarity:"):
                    try:
                        max_sim = float(line.strip().split(":")[1])
                    except:
                        pass
            if db_pair and max_sim is not None:
                similarity_data.append((filename, max_sim, db_pair[0], db_pair[1]))

similarity_data.sort(key=lambda x: x[1])
top10 = similarity_data[:10]

output_dir = "least_similarity_pairs"
os.makedirs(output_dir, exist_ok=True)

for i, (fname, sim, db1, db2) in enumerate(top10):
    outname = f"{i+1:02d}_{fname}"
    outpath = os.path.join(output_dir, outname)
    with open(outpath, "w") as out:
        out.write(f"{fname}\t{sim:.4f}\n\n")
        out.write(f"===== Schema for {db1} =====\n")
        out.write(capture_print_schema(db1) + "\n")
        out.write(f"\n===== Schema for {db2} =====\n")
        out.write(capture_print_schema(db2) + "\n")

# %%
import os

# 源目录
directory = "/hpctmp/e1351271/wkdbs/out/random_pairs_max_similarity_10k"

# 存储提取结果
extracted = []

# 遍历所有文件
for filename in os.listdir(directory):
    if "_" in filename:
        parts = filename.split("_")
        if len(parts) >= 2:
            # 提取第二个下划线前的部分（即前两个parts合并）
            extracted.append(f"{parts[0]}_{parts[1]}")

# 去重（可选）
extracted = list(set(extracted))

# 保存到文件
with open("sample_pairs_10k.txt", "w") as f:
    for item in extracted:
        f.write(item + "\n")

# %%
import pandas as pd
import itertools
import csv

def convert_duplicate_qids_to_pair_csv_with_qid(
    input_csv="/hpctmp/e1351271/wkdbs/data/duplicate_qids.csv",
    output_csv="/hpctmp/e1351271/wkdbs/data/qid_pairs.csv"
):
    df = pd.read_csv(input_csv)
    pairs = []

    for _, row in df.iterrows():
        qid = row["Q-ID"]
        dbs = [db.strip().split("_")[0] for db in row["Databases"].split(";") if db.strip()]
        for db1, db2 in itertools.combinations(dbs, 2):
            print(db1, db2, qid)
            pairs.append((db1, db2, qid))  # ✅ 保留 qid

    # 去重
    unique_pairs = list(set(pairs))

    # 写入 CSV
    with open(output_csv, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["db1", "db2", "qid"])  # ✅ header 包含 qid
        for db1, db2, qid in unique_pairs:
            writer.writerow([db1, db2, qid])

    print(f"✅ Saved {len(unique_pairs)} pairs WITH QID to {output_csv}")


convert_duplicate_qids_to_pair_csv_with_qid()
# Out:
# 98018 63035 Q16868
# 42581 58223 Q164735
# 03603 59772 Q1489
# 03603 27229 Q1489
# 59772 27229 Q1489
# 63835 30121 Q5968
# 40821 52883 Q8646
# 40821 92311 Q8646
# 40821 56849 Q8646
# 40821 00895 Q8646
# 40821 02918 Q8646
# 40821 65330 Q8646
# 40821 92081 Q8646
# 40821 07679 Q8646
# 52883 92311 Q8646
# 52883 56849 Q8646
# 52883 00895 Q8646
# 52883 02918 Q8646
# 52883 65330 Q8646
# 52883 92081 Q8646
# 52883 07679 Q8646
# 92311 56849 Q8646
# 92311 00895 Q8646
# 92311 02918 Q8646
# 92311 65330 Q8646
# 92311 92081 Q8646
# 92311 07679 Q8646
# 56849 00895 Q8646
# 56849 02918 Q8646
# 56849 65330 Q8646
# 56849 92081 Q8646
# 56849 07679 Q8646
# 00895 02918 Q8646
# 00895 65330 Q8646
# 00895 92081 Q8646
# 00895 07679 Q8646
# 02918 65330 Q8646
# 02918 92081 Q8646
# 02918 07679 Q8646
# 65330 92081 Q8646
# 65330 07679 Q8646
# 92081 07679 Q8646
# 66266 88685 Q736
# 66266 64857 Q736
# 66266 40059 Q736
# 88685 64857 Q736
# 88685 40059 Q736
# 64857 40059 Q736
# 72697 41654 Q1490
# 72697 07830 Q1490
# 72697 96274 Q1490
# 72697 29618 Q1490
# 72697 35446 Q1490
# 72697 92546 Q1490
# 41654 07830 Q1490
# 41654 96274 Q1490
# 41654 29618 Q1490
# 41654 35446 Q1490
# 41654 92546 Q1490
# 07830 96274 Q1490
# 07830 29618 Q1490
# 07830 35446 Q1490
# 07830 92546 Q1490
# 96274 29618 Q1490
# 96274 35446 Q1490
# 96274 92546 Q1490
# 29618 35446 Q1490
# 29618 92546 Q1490
# 35446 92546 Q1490
# 12807 64008 Q11032
# 12807 86677 Q11032
# 64008 86677 Q11032
# 74986 05648 Q9682
# 74986 56680 Q9682
# 05648 56680 Q9682
# 86553 14352 Q191
# 86553 61645 Q191
# 86553 37293 Q191
# 86553 24831 Q191
# 86553 84640 Q191
# 86553 16848 Q191
# 14352 61645 Q191
# 14352 37293 Q191
# 14352 24831 Q191
# 14352 84640 Q191
# 14352 16848 Q191
# 61645 37293 Q191
# 61645 24831 Q191
# 61645 84640 Q191
# 61645 16848 Q191
# 37293 24831 Q191
# 37293 84640 Q191
# 37293 16848 Q191
# 24831 84640 Q191
# 24831 16848 Q191
# 84640 16848 Q191
# 18869 60945 Q933927
# 54653 49756 Q953
# 54653 23337 Q953
# 49756 23337 Q953
# 06279 65667 Q11059
# 06279 92251 Q11059
# 65667 92251 Q11059
# 00707 88086 Q108325
# 07809 92850 Q958
# 07809 55938 Q958
# 92850 55938 Q958
# 90383 38551 Q47521
# 80780 51967 Q157053
# 80780 46651 Q157053
# 51967 46651 Q157053
# 59529 65281 Q127
# 05190 94951 Q12640
# 55271 31823 Q55269
# 32050 78422 Q1165943
# 44993 86535 Q460162
# 66936 37298 Q740863
# 91469 88950 Q190805
# 26482 68257 Q21157748
# 81971 29245 Q12829733
# 81971 03255 Q12829733
# 81971 37784 Q12829733
# 29245 03255 Q12829733
# 29245 37784 Q12829733
# 03255 37784 Q12829733
# 71864 82830 Q5203634
# 47716 76975 Q1062026
# 53178 14869 Q9676
# 53178 38982 Q9676
# 14869 38982 Q9676
# 51704 86524 Q1085
# 51704 25497 Q1085
# 51704 39468 Q1085
# 51704 02182 Q1085
# 51704 64367 Q1085
# 51704 30691 Q1085
# 86524 25497 Q1085
# 86524 39468 Q1085
# 86524 02182 Q1085
# 86524 64367 Q1085
# 86524 30691 Q1085
# 25497 39468 Q1085
# 25497 02182 Q1085
# 25497 64367 Q1085
# 25497 30691 Q1085
# 39468 02182 Q1085
# 39468 64367 Q1085
# 39468 30691 Q1085
# 02182 64367 Q1085
# 02182 30691 Q1085
# 64367 30691 Q1085
# 07284 88454 Q44687
# 61380 40362 Q115114034
# 12886 99996 Q902
# 12886 44209 Q902
# 12886 02289 Q902
# 99996 44209 Q902
# 99996 02289 Q902
# 44209 02289 Q902
# 05924 90445 Q217829
# 82126 32520 Q7260970
# 59415 29446 Q744948
# 83741 11102 Q9043
# 29378 52447 Q104877
# 48398 66413 Q17488930
# 68867 80697 Q10406928
# 15543 88777 Q26600
# 15543 22874 Q26600
# 15543 99399 Q26600
# 88777 22874 Q26600
# 88777 99399 Q26600
# 22874 99399 Q26600
# 44261 97592 Q476288
# 86325 27009 Q68347643
# 10640 79273 Q224
# 10640 41148 Q224
# 10640 03565 Q224
# 10640 15610 Q224
# 10640 04760 Q224
# 10640 73689 Q224
# 79273 41148 Q224
# 79273 03565 Q224
# 79273 15610 Q224
# 79273 04760 Q224
# 79273 73689 Q224
# 41148 03565 Q224
# 41148 15610 Q224
# 41148 04760 Q224
# 41148 73689 Q224
# 03565 15610 Q224
# 03565 04760 Q224
# 03565 73689 Q224
# 15610 04760 Q224
# 15610 73689 Q224
# 04760 73689 Q224
# 56947 84660 Q7566955
# 30305 64811 Q983
# 30305 13417 Q983
# 30305 05542 Q983
# 30305 16265 Q983
# 64811 13417 Q983
# 64811 05542 Q983
# 64811 16265 Q983
# 13417 05542 Q983
# 13417 16265 Q983
# 05542 16265 Q983
# 80549 63487 Q1252971
# 80549 29101 Q1252971
# 63487 29101 Q1252971
# 35483 79287 Q16584911
# 28896 97606 Q289
# 78147 96785 Q841014
# 21518 00702 Q83324
# 01321 70034 Q260320
# 04552 91552 Q31331
# 67803 59628 Q1659468
# 46163 54460 Q7252
# 46163 94923 Q7252
# 54460 94923 Q7252
# 82929 97550 Q12404
# 61356 03065 Q178025
# 99597 26822 Q5589
# 40127 53780 Q766
# 40127 86820 Q766
# 40127 90897 Q766
# 40127 00238 Q766
# 53780 86820 Q766
# 53780 90897 Q766
# 53780 00238 Q766
# 86820 90897 Q766
# 86820 00238 Q766
# 90897 00238 Q766
# 33057 45304 Q854
# 33057 36262 Q854
# 45304 36262 Q854
# 00799 77353 Q2066
# 27363 06724 Q256
# 27363 25141 Q256
# 06724 25141 Q256
# 84779 07481 Q4925916
# 65602 17889 Q833271
# 29258 02082 Q984998
# 10670 32570 Q256020
# 10670 99471 Q256020
# 32570 99471 Q256020
# 72147 87539 Q858
# 72147 92037 Q858
# 72147 31465 Q858
# 72147 85868 Q858
# 72147 91611 Q858
# 72147 98183 Q858
# 72147 17804 Q858
# 72147 16399 Q858
# 87539 92037 Q858
# 87539 31465 Q858
# 87539 85868 Q858
# 87539 91611 Q858
# 87539 98183 Q858
# 87539 17804 Q858
# 87539 16399 Q858
# 92037 31465 Q858
# 92037 85868 Q858
# 92037 91611 Q858
# 92037 98183 Q858
# 92037 17804 Q858
# 92037 16399 Q858
# 31465 85868 Q858
# 31465 91611 Q858
# 31465 98183 Q858
# 31465 17804 Q858
# 31465 16399 Q858
# 85868 91611 Q858
# 85868 98183 Q858
# 85868 17804 Q858
# 85868 16399 Q858
# 91611 98183 Q858
# 91611 17804 Q858
# 91611 16399 Q858
# 98183 17804 Q858
# 98183 16399 Q858
# 17804 16399 Q858
# 56006 33450 Q863
# 56006 52272 Q863
# 56006 11956 Q863
# 56006 23393 Q863
# 33450 52272 Q863
# 33450 11956 Q863
# 33450 23393 Q863
# 52272 11956 Q863
# 52272 23393 Q863
# 11956 23393 Q863
# 87498 22343 Q1973
# 08170 47785 Q184296
# 04851 01512 Q8356
# 00017 21190 Q128936
# 09135 78709 Q170287
# 70811 37705 Q29364
# 07885 91979 Q237
# 56455 43362 Q804356
# 32883 46599 Q81545
# 90348 10435 Q600614
# 47597 53997 Q757240
# 94225 69941 Q48954
# 12719 50170 Q499510
# 12719 87230 Q499510
# 12719 42608 Q499510
# 50170 87230 Q499510
# 50170 42608 Q499510
# 87230 42608 Q499510
# 66793 16806 Q1023810
# 88334 33666 Q948
# 88334 79354 Q948
# 88334 61794 Q948
# 88334 19687 Q948
# 33666 79354 Q948
# 33666 61794 Q948
# 33666 19687 Q948
# 79354 61794 Q948
# 79354 19687 Q948
# 61794 19687 Q948
# 01980 02603 Q777337
# 08982 14976 Q93184
# 02570 83191 Q769
# 02570 66130 Q769
# 83191 66130 Q769
# 55328 71737 Q40
# 55328 41765 Q40
# 55328 80655 Q40
# 55328 41880 Q40
# 71737 41765 Q40
# 71737 80655 Q40
# 71737 41880 Q40
# 41765 80655 Q40
# 41765 41880 Q40
# 80655 41880 Q40
# 38276 06319 Q1107656
# 38276 63336 Q1107656
# 06319 63336 Q1107656
# 75933 99388 Q11244
# 23970 65252 Q8835
# 23970 57671 Q8835
# 65252 57671 Q8835
# 06733 89893 Q15499
# 21152 64748 Q1605091
# 27296 95745 Q35
# 27296 55257 Q35
# 27296 84778 Q35
# 27296 57961 Q35
# 27296 87437 Q35
# 95745 55257 Q35
# 95745 84778 Q35
# 95745 57961 Q35
# 95745 87437 Q35
# 55257 84778 Q35
# 55257 57961 Q35
# 55257 87437 Q35
# 84778 57961 Q35
# 84778 87437 Q35
# 57961 87437 Q35
# 25337 37455 Q424
# 25337 17700 Q424
# 25337 02612 Q424
# 25337 51017 Q424
# 25337 21502 Q424
# 25337 36927 Q424
# 37455 17700 Q424
# 37455 02612 Q424
# 37455 51017 Q424
# 37455 21502 Q424
# 37455 36927 Q424
# 17700 02612 Q424
# 17700 51017 Q424
# 17700 21502 Q424
# 17700 36927 Q424
# 02612 51017 Q424
# 02612 21502 Q424
# 02612 36927 Q424
# 51017 21502 Q424
# 51017 36927 Q424
# 21502 36927 Q424
# 47412 43725 Q696407
# 12547 78455 Q819121
# 72332 54758 Q210447
# 62136 93194 Q14808
# 31388 57993 Q56423319
# 09388 46024 Q319654
# 01131 85257 Q98668653
# 01131 20306 Q98668653
# 01131 09131 Q98668653
# 85257 20306 Q98668653
# 85257 09131 Q98668653
# 20306 09131 Q98668653
# 17731 07545 Q211
# 17731 22237 Q211
# 17731 12769 Q211
# 17731 08748 Q211
# 17731 20725 Q211
# 17731 44111 Q211
# 17731 05031 Q211
# 17731 54176 Q211
# 17731 80002 Q211
# 07545 22237 Q211
# 07545 12769 Q211
# 07545 08748 Q211
# 07545 20725 Q211
# 07545 44111 Q211
# 07545 05031 Q211
# 07545 54176 Q211
# 07545 80002 Q211
# 22237 12769 Q211
# 22237 08748 Q211
# 22237 20725 Q211
# 22237 44111 Q211
# 22237 05031 Q211
# 22237 54176 Q211
# 22237 80002 Q211
# 12769 08748 Q211
# 12769 20725 Q211
# 12769 44111 Q211
# 12769 05031 Q211
# 12769 54176 Q211
# 12769 80002 Q211
# 08748 20725 Q211
# 08748 44111 Q211
# 08748 05031 Q211
# 08748 54176 Q211
# 08748 80002 Q211
# 20725 44111 Q211
# 20725 05031 Q211
# 20725 54176 Q211
# 20725 80002 Q211
# 44111 05031 Q211
# 44111 54176 Q211
# 44111 80002 Q211
# 05031 54176 Q211
# 05031 80002 Q211
# 54176 80002 Q211
# 35357 68203 Q16
# 35357 38034 Q16
# 35357 91213 Q16
# 35357 18688 Q16
# 35357 00509 Q16
# 35357 91647 Q16
# 35357 81136 Q16
# 35357 62435 Q16
# 35357 91468 Q16
# 68203 38034 Q16
# 68203 91213 Q16
# 68203 18688 Q16
# 68203 00509 Q16
# 68203 91647 Q16
# 68203 81136 Q16
# 68203 62435 Q16
# 68203 91468 Q16
# 38034 91213 Q16
# 38034 18688 Q16
# 38034 00509 Q16
# 38034 91647 Q16
# 38034 81136 Q16
# 38034 62435 Q16
# 38034 91468 Q16
# 91213 18688 Q16
# 91213 00509 Q16
# 91213 91647 Q16
# 91213 81136 Q16
# 91213 62435 Q16
# 91213 91468 Q16
# 18688 00509 Q16
# 18688 91647 Q16
# 18688 81136 Q16
# 18688 62435 Q16
# 18688 91468 Q16
# 00509 91647 Q16
# 00509 81136 Q16
# 00509 62435 Q16
# 00509 91468 Q16
# 91647 81136 Q16
# 91647 62435 Q16
# 91647 91468 Q16
# 81136 62435 Q16
# 81136 91468 Q16
# 62435 91468 Q16
# 49505 05216 Q685935
# 55858 20641 Q205764
# 06757 16860 Q552511
# 89107 86550 Q1861
# 89107 89949 Q1861
# 86550 89949 Q1861
# 75092 45910 Q1144883
# 55166 99408 Q739
# 55166 65063 Q739
# 55166 40392 Q739
# 99408 65063 Q739
# 99408 40392 Q739
# 65063 40392 Q739
# 89397 08302 Q646388
# 11419 55529 Q16881239
# 47344 71971 Q35323
# 05594 07415 Q616620
# 38851 65614 Q23413
# 38851 46111 Q23413
# 38851 66122 Q23413
# 65614 46111 Q23413
# 65614 66122 Q23413
# 46111 66122 Q23413
# 66455 40691 Q1206
# 47242 58161 Q161944
# 22158 03525 Q20743580
# 16393 29640 Q35986
# 30572 43008 Q55392
# 30572 47793 Q55392
# 43008 47793 Q55392
# 26845 35642 Q771
# 26845 00902 Q771
# 35642 00902 Q771
# 37012 19960 Q167346
# 01473 33187 Q56760488
# 50068 84728 Q128069
# 25162 13326 Q331432
# 24358 38256 Q34201
# 01681 90347 Q1138610
# 65358 28806 Q80560
# 28007 81480 Q5369517
# 54271 66249 Q190828
# 54271 43049 Q190828
# 66249 43049 Q190828
# 63676 19436 Q95380
# 86030 16705 Q31487
# 86030 32839 Q31487
# 86030 10256 Q31487
# 16705 32839 Q31487
# 16705 10256 Q31487
# 32839 10256 Q31487
# 11315 45412 Q184784
# 11315 05022 Q184784
# 45412 05022 Q184784
# 91507 98678 Q76473
# 91507 95363 Q76473
# 98678 95363 Q76473
# 85392 94376 Q834280
# 99740 70521 Q10803202
# 33254 53693 Q80011
# 96748 46008 Q139399
# 79715 40845 Q494001
# 46269 50909 Q142
# 46269 47616 Q142
# 46269 91964 Q142
# 46269 80423 Q142
# 46269 83769 Q142
# 46269 40846 Q142
# 46269 47335 Q142
# 46269 75652 Q142
# 46269 10474 Q142
# 50909 47616 Q142
# 50909 91964 Q142
# 50909 80423 Q142
# 50909 83769 Q142
# 50909 40846 Q142
# 50909 47335 Q142
# 50909 75652 Q142
# 50909 10474 Q142
# 47616 91964 Q142
# 47616 80423 Q142
# 47616 83769 Q142
# 47616 40846 Q142
# 47616 47335 Q142
# 47616 75652 Q142
# 47616 10474 Q142
# 91964 80423 Q142
# 91964 83769 Q142
# 91964 40846 Q142
# 91964 47335 Q142
# 91964 75652 Q142
# 91964 10474 Q142
# 80423 83769 Q142
# 80423 40846 Q142
# 80423 47335 Q142
# 80423 75652 Q142
# 80423 10474 Q142
# 83769 40846 Q142
# 83769 47335 Q142
# 83769 75652 Q142
# 83769 10474 Q142
# 40846 47335 Q142
# 40846 75652 Q142
# 40846 10474 Q142
# 47335 75652 Q142
# 47335 10474 Q142
# 75652 10474 Q142
# 32273 18990 Q14599311
# 17676 42103 Q16957
# 17676 04490 Q16957
# 42103 04490 Q16957
# 03812 41211 Q122962941
# 32807 48271 Q2919386
# 07433 03601 Q495
# 07433 53152 Q495
# 07433 77694 Q495
# 07433 74305 Q495
# 07433 15939 Q495
# 07433 89155 Q495
# 07433 75367 Q495
# 03601 53152 Q495
# 03601 77694 Q495
# 03601 74305 Q495
# 03601 15939 Q495
# 03601 89155 Q495
# 03601 75367 Q495
# 53152 77694 Q495
# 53152 74305 Q495
# 53152 15939 Q495
# 53152 89155 Q495
# 53152 75367 Q495
# 77694 74305 Q495
# 77694 15939 Q495
# 77694 89155 Q495
# 77694 75367 Q495
# 74305 15939 Q495
# 74305 89155 Q495
# 74305 75367 Q495
# 15939 89155 Q495
# 15939 75367 Q495
# 89155 75367 Q495
# 97272 37679 Q185632
# 15115 07278 Q133948
# 90420 81635 Q2044
# 90420 86714 Q2044
# 90420 94809 Q2044
# 81635 86714 Q2044
# 81635 94809 Q2044
# 86714 94809 Q2044
# 18164 09056 Q13013643
# 37508 70444 Q858439
# 32372 47787 Q188822
# 94876 50591 Q6157354
# 46249 06182 Q1403486
# 65741 79165 Q182872
# 09230 66861 Q1257318
# 95599 70770 Q27450520
# 79201 68640 Q5176750
# 07122 49158 Q8031191
# 98267 51907 Q210189
# 10729 79888 Q39109
# 10729 71314 Q39109
# 79888 71314 Q39109
# 01799 24781 Q1055
# 01799 77459 Q1055
# 01799 64977 Q1055
# 01799 42948 Q1055
# 01799 15301 Q1055
# 24781 77459 Q1055
# 24781 64977 Q1055
# 24781 42948 Q1055
# 24781 15301 Q1055
# 77459 64977 Q1055
# 77459 42948 Q1055
# 77459 15301 Q1055
# 64977 42948 Q1055
# 64977 15301 Q1055
# 42948 15301 Q1055
# 63888 36310 Q16969880
# 53304 60408 Q393439
# 12955 75814 Q1191191
# 55356 03337 Q1492
# 55356 80285 Q1492
# 55356 64626 Q1492
# 55356 48413 Q1492
# 55356 62521 Q1492
# 55356 08876 Q1492
# 55356 30151 Q1492
# 03337 80285 Q1492
# 03337 64626 Q1492
# 03337 48413 Q1492
# 03337 62521 Q1492
# 03337 08876 Q1492
# 03337 30151 Q1492
# 80285 64626 Q1492
# 80285 48413 Q1492
# 80285 62521 Q1492
# 80285 08876 Q1492
# 80285 30151 Q1492
# 64626 48413 Q1492
# 64626 62521 Q1492
# 64626 08876 Q1492
# 64626 30151 Q1492
# 48413 62521 Q1492
# 48413 08876 Q1492
# 48413 30151 Q1492
# 62521 08876 Q1492
# 62521 30151 Q1492
# 08876 30151 Q1492
# 04971 67248 Q24398318
# 71294 18349 Q30642
# 65450 30608 Q227
# 65450 00112 Q227
# 65450 88072 Q227
# 65450 36376 Q227
# 65450 11323 Q227
# 30608 00112 Q227
# 30608 88072 Q227
# 30608 36376 Q227
# 30608 11323 Q227
# 00112 88072 Q227
# 00112 36376 Q227
# 00112 11323 Q227
# 88072 36376 Q227
# 88072 11323 Q227
# 36376 11323 Q227
# 46578 85068 Q60571270
# 30298 50861 Q1770
# 30298 51592 Q1770
# 50861 51592 Q1770
# 37466 42760 Q224124
# 37466 01230 Q224124
# 42760 01230 Q224124
# 25236 66083 Q3769299
# 95413 42390 Q21637
# 84990 85805 Q3377
# 51972 39561 Q55234
# 62267 70558 Q83459
# 77209 56775 Q15982573
# 66080 97546 Q1721
# 66080 59429 Q1721
# 97546 59429 Q1721
# 80828 11575 Q1207735
# 22011 86700 Q18438
# 22011 87748 Q18438
# 86700 87748 Q18438
# 85005 12431 Q984508
# 98243 65457 Q129649
# 44142 77576 Q5360000
# 76669 13776 Q21191270
# 76669 91040 Q21191270
# 13776 91040 Q21191270
# 23657 11644 Q378622
# 95352 19328 Q18094
# 95352 52618 Q18094
# 19328 52618 Q18094
# 01615 37247 Q183560
# 63542 06607 Q1055522
# 35898 38354 Q254235
# 80347 08931 Q25882
# 81199 00103 Q5237
# 81199 34062 Q5237
# 00103 34062 Q5237
# 23452 15591 Q20804433
# 35792 48991 Q220
# 35792 69442 Q220
# 35792 10164 Q220
# 35792 03217 Q220
# 35792 33445 Q220
# 48991 69442 Q220
# 48991 10164 Q220
# 48991 03217 Q220
# 48991 33445 Q220
# 69442 10164 Q220
# 69442 03217 Q220
# 69442 33445 Q220
# 10164 03217 Q220
# 10164 33445 Q220
# 03217 33445 Q220
# 74140 49386 Q40970
# 49801 48927 Q1858
# 75507 33681 Q2322
# 86504 59073 Q9683
# 39883 64546 Q8514
# 10096 66993 Q1715
# 10096 86812 Q1715
# 10096 67762 Q1715
# 10096 33648 Q1715
# 10096 45687 Q1715
# 66993 86812 Q1715
# 66993 67762 Q1715
# 66993 33648 Q1715
# 66993 45687 Q1715
# 86812 67762 Q1715
# 86812 33648 Q1715
# 86812 45687 Q1715
# 67762 33648 Q1715
# 67762 45687 Q1715
# 33648 45687 Q1715
# 21173 92020 Q23307832
# 92735 21041 Q7150
# 67547 67782 Q8717
# 75190 65403 Q21
# 75190 43386 Q21
# 75190 22638 Q21
# 75190 17758 Q21
# 75190 93863 Q21
# 65403 43386 Q21
# 65403 22638 Q21
# 65403 17758 Q21
# 65403 93863 Q21
# 43386 22638 Q21
# 43386 17758 Q21
# 43386 93863 Q21
# 22638 17758 Q21
# 22638 93863 Q21
# 17758 93863 Q21
# 33797 36793 Q206297
# 27914 54808 Q5087708
# 68668 55628 Q36687
# 68668 37224 Q36687
# 55628 37224 Q36687
# 36316 70461 Q3934
# 18362 51413 Q29515313
# 31553 60543 Q17592
# 45608 49896 Q1030
# 45608 80218 Q1030
# 45608 36489 Q1030
# 45608 19599 Q1030
# 49896 80218 Q1030
# 49896 36489 Q1030
# 49896 19599 Q1030
# 80218 36489 Q1030
# 80218 19599 Q1030
# 36489 19599 Q1030
# 18684 30819 Q15174
# 18684 81245 Q15174
# 30819 81245 Q15174
# 45777 02254 Q7929224
# 49424 84432 Q9610
# 49424 24129 Q9610
# 49424 18617 Q9610
# 49424 47236 Q9610
# 84432 24129 Q9610
# 84432 18617 Q9610
# 84432 47236 Q9610
# 24129 18617 Q9610
# 24129 47236 Q9610
# 18617 47236 Q9610
# 04010 13600 Q7895888
# 30449 21441 Q935
# 31554 84920 Q718
# 31554 55641 Q718
# 84920 55641 Q718
# 39691 23193 Q2150
# 39691 65379 Q2150
# 23193 65379 Q2150
# 81570 44998 Q690
# 81570 08635 Q690
# 81570 47594 Q690
# 44998 08635 Q690
# 44998 47594 Q690
# 08635 47594 Q690
# 28562 25350 Q39
# 28562 46871 Q39
# 28562 52508 Q39
# 28562 99395 Q39
# 28562 80278 Q39
# 28562 92341 Q39
# 25350 46871 Q39
# 25350 52508 Q39
# 25350 99395 Q39
# 25350 80278 Q39
# 25350 92341 Q39
# 46871 52508 Q39
# 46871 99395 Q39
# 46871 80278 Q39
# 46871 92341 Q39
# 52508 99395 Q39
# 52508 80278 Q39
# 52508 92341 Q39
# 99395 80278 Q39
# 99395 92341 Q39
# 80278 92341 Q39
# 01119 70563 Q208473
# 48973 72033 Q23851295
# 33164 26494 Q282428
# 33164 45700 Q282428
# 26494 45700 Q282428
# 43842 89355 Q12994
# 43842 39315 Q12994
# 89355 39315 Q12994
# 05039 28334 Q399
# 05039 63395 Q399
# 05039 76710 Q399
# 05039 01347 Q399
# 05039 67018 Q399
# 05039 72021 Q399
# 28334 63395 Q399
# 28334 76710 Q399
# 28334 01347 Q399
# 28334 67018 Q399
# 28334 72021 Q399
# 63395 76710 Q399
# 63395 01347 Q399
# 63395 67018 Q399
# 63395 72021 Q399
# 76710 01347 Q399
# 76710 67018 Q399
# 76710 72021 Q399
# 01347 67018 Q399
# 01347 72021 Q399
# 67018 72021 Q399
# 02543 77015 Q597
# 02543 92942 Q597
# 02543 20946 Q597
# 02543 74067 Q597
# 02543 50994 Q597
# 77015 92942 Q597
# 77015 20946 Q597
# 77015 74067 Q597
# 77015 50994 Q597
# 92942 20946 Q597
# 92942 74067 Q597
# 92942 50994 Q597
# 20946 74067 Q597
# 20946 50994 Q597
# 74067 50994 Q597
# 39456 23962 Q788345
# 25159 10746 Q4824612
# 23232 51565 Q309350
# 71863 58697 Q95
# 71863 93390 Q95
# 58697 93390 Q95
# 58146 95214 Q19692233
# 15824 86739 Q410352
# 46147 65914 Q1752459
# 18614 74937 Q11954
# 43103 57590 Q25331
# 82199 75936 Q13139
# 81509 55911 Q865
# 81509 58872 Q865
# 81509 87930 Q865
# 81509 75800 Q865
# 81509 28309 Q865
# 81509 68443 Q865
# 81509 73941 Q865
# 55911 58872 Q865
# 55911 87930 Q865
# 55911 75800 Q865
# 55911 28309 Q865
# 55911 68443 Q865
# 55911 73941 Q865
# 58872 87930 Q865
# 58872 75800 Q865
# 58872 28309 Q865
# 58872 68443 Q865
# 58872 73941 Q865
# 87930 75800 Q865
# 87930 28309 Q865
# 87930 68443 Q865
# 87930 73941 Q865
# 75800 28309 Q865
# 75800 68443 Q865
# 75800 73941 Q865
# 28309 68443 Q865
# 28309 73941 Q865
# 68443 73941 Q865
# 89188 42003 Q35775
# 89188 08695 Q35775
# 42003 08695 Q35775
# 12673 29981 Q366231
# 22767 43735 Q205380
# 22767 70841 Q205380
# 43735 70841 Q205380
# 63116 10925 Q501875
# 13677 23444 Q1049066
# 89010 94446 Q689400
# 18363 85103 Q96
# 18363 94962 Q96
# 18363 34082 Q96
# 18363 83988 Q96
# 18363 10194 Q96
# 18363 03614 Q96
# 85103 94962 Q96
# 85103 34082 Q96
# 85103 83988 Q96
# 85103 10194 Q96
# 85103 03614 Q96
# 94962 34082 Q96
# 94962 83988 Q96
# 94962 10194 Q96
# 94962 03614 Q96
# 34082 83988 Q96
# 34082 10194 Q96
# 34082 03614 Q96
# 83988 10194 Q96
# 83988 03614 Q96
# 10194 03614 Q96
# 14176 17780 Q472
# 14176 58538 Q472
# 14176 20708 Q472
# 17780 58538 Q472
# 17780 20708 Q472
# 58538 20708 Q472
# 40721 84493 Q2675537
# 50678 34924 Q43300
# 65417 07290 Q201076
# 59306 71288 Q2996394
# 61493 08966 Q7332604
# 20468 05748 Q115
# 20468 14344 Q115
# 20468 02988 Q115
# 05748 14344 Q115
# 05748 02988 Q115
# 14344 02988 Q115
# 00037 74901 Q191106
# 13551 22234 Q38234
# 13551 89463 Q38234
# 22234 89463 Q38234
# 94971 95142 Q6918773
# 49202 74261 Q114
# 49202 63592 Q114
# 49202 98353 Q114
# 49202 74602 Q114
# 49202 63167 Q114
# 49202 74528 Q114
# 74261 63592 Q114
# 74261 98353 Q114
# 74261 74602 Q114
# 74261 63167 Q114
# 74261 74528 Q114
# 63592 98353 Q114
# 63592 74602 Q114
# 63592 63167 Q114
# 63592 74528 Q114
# 98353 74602 Q114
# 98353 63167 Q114
# 98353 74528 Q114
# 74602 63167 Q114
# 74602 74528 Q114
# 63167 74528 Q114
# 10933 21606 Q5015526
# 05925 31144 Q1617
# 49459 53856 Q21066169
# 26283 10289 Q487096
# 26283 70236 Q487096
# 10289 70236 Q487096
# 74716 16768 Q62942
# 11780 86351 Q252
# 11780 65471 Q252
# 11780 93460 Q252
# 11780 50609 Q252
# 11780 15589 Q252
# 11780 12432 Q252
# 11780 03524 Q252
# 11780 23424 Q252
# 11780 45011 Q252
# 11780 75594 Q252
# 86351 65471 Q252
# 86351 93460 Q252
# 86351 50609 Q252
# 86351 15589 Q252
# 86351 12432 Q252
# 86351 03524 Q252
# 86351 23424 Q252
# 86351 45011 Q252
# 86351 75594 Q252
# 65471 93460 Q252
# 65471 50609 Q252
# 65471 15589 Q252
# 65471 12432 Q252
# 65471 03524 Q252
# 65471 23424 Q252
# 65471 45011 Q252
# 65471 75594 Q252
# 93460 50609 Q252
# 93460 15589 Q252
# 93460 12432 Q252
# 93460 03524 Q252
# 93460 23424 Q252
# 93460 45011 Q252
# 93460 75594 Q252
# 50609 15589 Q252
# 50609 12432 Q252
# 50609 03524 Q252
# 50609 23424 Q252
# 50609 45011 Q252
# 50609 75594 Q252
# 15589 12432 Q252
# 15589 03524 Q252
# 15589 23424 Q252
# 15589 45011 Q252
# 15589 75594 Q252
# 12432 03524 Q252
# 12432 23424 Q252
# 12432 45011 Q252
# 12432 75594 Q252
# 03524 23424 Q252
# 03524 45011 Q252
# 03524 75594 Q252
# 23424 45011 Q252
# 23424 75594 Q252
# 45011 75594 Q252
# 61328 48639 Q35499
# 60510 79332 Q482724
# 26887 07617 Q9696
# 59619 35450 Q6548
# 59619 77626 Q6548
# 59619 99475 Q6548
# 59619 94786 Q6548
# 35450 77626 Q6548
# 35450 99475 Q6548
# 35450 94786 Q6548
# 77626 99475 Q6548
# 77626 94786 Q6548
# 99475 94786 Q6548
# 34395 27155 Q638
# 00369 08551 Q187326
# 93761 94404 Q21344411
# 93761 52225 Q21344411
# 94404 52225 Q21344411
# 19659 92415 Q23442
# 19659 65408 Q23442
# 19659 30176 Q23442
# 19659 40467 Q23442
# 19659 83134 Q23442
# 92415 65408 Q23442
# 92415 30176 Q23442
# 92415 40467 Q23442
# 92415 83134 Q23442
# 65408 30176 Q23442
# 65408 40467 Q23442
# 65408 83134 Q23442
# 30176 40467 Q23442
# 30176 83134 Q23442
# 40467 83134 Q23442
# 40948 88791 Q13883136
# 82394 28066 Q298
# 82394 55852 Q298
# 82394 88447 Q298
# 82394 14804 Q298
# 82394 69854 Q298
# 82394 31489 Q298
# 82394 26407 Q298
# 28066 55852 Q298
# 28066 88447 Q298
# 28066 14804 Q298
# 28066 69854 Q298
# 28066 31489 Q298
# 28066 26407 Q298
# 55852 88447 Q298
# 55852 14804 Q298
# 55852 69854 Q298
# 55852 31489 Q298
# 55852 26407 Q298
# 88447 14804 Q298
# 88447 69854 Q298
# 88447 31489 Q298
# 88447 26407 Q298
# 14804 69854 Q298
# 14804 31489 Q298
# 14804 26407 Q298
# 69854 31489 Q298
# 69854 26407 Q298
# 31489 26407 Q298
# 67395 52387 Q54829
# 67395 27506 Q54829
# 52387 27506 Q54829
# 47448 04087 Q1014
# 47448 90930 Q1014
# 04087 90930 Q1014
# 07822 36311 Q131626
# 94054 34138 Q36074
# 68161 22091 Q8108
# 68161 56406 Q8108
# 22091 56406 Q8108
# 77318 97543 Q120730
# 99719 47449 Q144786
# 63791 31367 Q15268054
# 48104 11227 Q382844
# 30487 13760 Q971
# 21558 65491 Q72672
# 19223 12633 Q45
# 19223 52300 Q45
# 19223 19638 Q45
# 19223 98819 Q45
# 19223 30023 Q45
# 19223 00154 Q45
# 19223 87679 Q45
# 12633 52300 Q45
# 12633 19638 Q45
# 12633 98819 Q45
# 12633 30023 Q45
# 12633 00154 Q45
# 12633 87679 Q45
# 52300 19638 Q45
# 52300 98819 Q45
# 52300 30023 Q45
# 52300 00154 Q45
# 52300 87679 Q45
# 19638 98819 Q45
# 19638 30023 Q45
# 19638 00154 Q45
# 19638 87679 Q45
# 98819 30023 Q45
# 98819 00154 Q45
# 98819 87679 Q45
# 30023 00154 Q45
# 30023 87679 Q45
# 00154 87679 Q45
# 64637 02510 Q1151091
# 58284 29722 Q9027
# 58284 37815 Q9027
# 58284 21779 Q9027
# 58284 77081 Q9027
# 58284 12868 Q9027
# 29722 37815 Q9027
# 29722 21779 Q9027
# 29722 77081 Q9027
# 29722 12868 Q9027
# 37815 21779 Q9027
# 37815 77081 Q9027
# 37815 12868 Q9027
# 21779 77081 Q9027
# 21779 12868 Q9027
# 77081 12868 Q9027
# 71260 96091 Q2090
# 71260 89270 Q2090
# 71260 95144 Q2090
# 71260 92786 Q2090
# 71260 78578 Q2090
# 96091 89270 Q2090
# 96091 95144 Q2090
# 96091 92786 Q2090
# 96091 78578 Q2090
# 89270 95144 Q2090
# 89270 92786 Q2090
# 89270 78578 Q2090
# 95144 92786 Q2090
# 95144 78578 Q2090
# 92786 78578 Q2090
# 63270 33890 Q20971580
# 63270 12220 Q20971580
# 33890 12220 Q20971580
# 04338 32624 Q26868933
# 06915 10157 Q30974
# 96254 68717 Q1194
# 96254 52229 Q1194
# 68717 52229 Q1194
# 34703 15011 Q333495
# 34703 04209 Q333495
# 15011 04209 Q333495
# 59700 14924 Q42365
# 91466 57871 Q36947
# 45628 91844 Q18699850
# 15066 19774 Q39111
# 87719 07398 Q26793
# 87719 18036 Q26793
# 07398 18036 Q26793
# 04400 28027 Q66569847
# 37156 53785 Q1342
# 37156 08758 Q1342
# 53785 08758 Q1342
# 48477 13728 Q9091
# 48477 00784 Q9091
# 13728 00784 Q9091
# 30237 07379 Q242
# 50240 53270 Q5908726
# 17550 62335 Q3511555
# 21947 74949 Q1640731
# 34232 66467 Q22806856
# 24075 64215 Q990168
# 03172 17603 Q763
# 02192 46342 Q3942
# 02537 35491 Q16520
# 02537 96226 Q16520
# 35491 96226 Q16520
# 19979 39821 Q919574
# 44239 39166 Q42722
# 87519 41617 Q459794
# 79007 55427 Q2696
# 47869 89493 Q4003020
# 15748 03191 Q170519
# 59093 19000 Q368105
# 64561 08788 Q72712
# 23265 59304 Q16511993
# 63108 00308 Q28099968
# 97139 31010 Q1458
# 12934 52244 Q527628
# 38727 56672 Q317814
# 73787 35997 Q159701
# 61971 10961 Q843799
# 92900 77386 Q348533
# 93942 25334 Q103148
# 61091 66479 Q131358
# 88781 68356 Q13595311
# 67937 09641 Q333329
# 83561 18748 Q12300343
# 48631 19252 Q834825
# 95581 75887 Q49261
# 98789 63661 Q122368957
# 04455 02770 Q23666
# 04455 90623 Q23666
# 04455 62675 Q23666
# 02770 90623 Q23666
# 02770 62675 Q23666
# 90623 62675 Q23666
# 62290 48137 Q380885
# 90039 26185 Q36600
# 90039 46353 Q36600
# 90039 35471 Q36600
# 26185 46353 Q36600
# 26185 35471 Q36600
# 46353 35471 Q36600
# 45939 81921 Q758853
# 19929 63706 Q180379
# 26508 42353 Q2785454
# 04189 59346 Q5004679
# 04189 19869 Q5004679
# 59346 19869 Q5004679
# 14659 93598 Q607190
# 46029 30769 Q7156
# 33946 06085 Q65
# 33946 18966 Q65
# 06085 18966 Q65
# 11434 52103 Q171617
# 80244 88296 Q649
# 80244 78316 Q649
# 80244 40979 Q649
# 80244 81573 Q649
# 88296 78316 Q649
# 88296 40979 Q649
# 88296 81573 Q649
# 78316 40979 Q649
# 78316 81573 Q649
# 40979 81573 Q649
# 78825 99727 Q14745
# 78825 79657 Q14745
# 78825 74493 Q14745
# 99727 79657 Q14745
# 99727 74493 Q14745
# 79657 74493 Q14745
# 29201 14004 Q80638
# 73720 93351 Q2705481
# 26290 59118 Q809892
# 89982 96636 Q186360
# 49126 13538 Q13924
# 75918 04364 Q43284
# 35771 03905 Q2417
# 00568 64047 Q219
# 00568 15517 Q219
# 00568 32160 Q219
# 00568 11842 Q219
# 00568 50175 Q219
# 00568 45959 Q219
# 64047 15517 Q219
# 64047 32160 Q219
# 64047 11842 Q219
# 64047 50175 Q219
# 64047 45959 Q219
# 15517 32160 Q219
# 15517 11842 Q219
# 15517 50175 Q219
# 15517 45959 Q219
# 32160 11842 Q219
# 32160 50175 Q219
# 32160 45959 Q219
# 11842 50175 Q219
# 11842 45959 Q219
# 50175 45959 Q219
# 48517 56304 Q38112
# 43114 12355 Q279681
# 43114 24571 Q279681
# 12355 24571 Q279681
# 41924 11396 Q850290
# 01685 50203 Q7286822
# 21113 98482 Q25
# 21113 14105 Q25
# 21113 32284 Q25
# 21113 05705 Q25
# 21113 58145 Q25
# 98482 14105 Q25
# 98482 32284 Q25
# 98482 05705 Q25
# 98482 58145 Q25
# 14105 32284 Q25
# 14105 05705 Q25
# 14105 58145 Q25
# 32284 05705 Q25
# 32284 58145 Q25
# 05705 58145 Q25
# 63875 67064 Q33578
# 81851 77385 Q1033
# 81851 59896 Q1033
# 81851 73676 Q1033
# 81851 69672 Q1033
# 81851 15081 Q1033
# 77385 59896 Q1033
# 77385 73676 Q1033
# 77385 69672 Q1033
# 77385 15081 Q1033
# 59896 73676 Q1033
# 59896 69672 Q1033
# 59896 15081 Q1033
# 73676 69672 Q1033
# 73676 15081 Q1033
# 69672 15081 Q1033
# 29336 10941 Q106058221
# 76930 00156 Q860994
# 21645 81365 Q665189
# 01310 49277 Q155904
# 79001 51000 Q1454
# 79001 57680 Q1454
# 79001 11302 Q1454
# 79001 93721 Q1454
# 51000 57680 Q1454
# 51000 11302 Q1454
# 51000 93721 Q1454
# 57680 11302 Q1454
# 57680 93721 Q1454
# 11302 93721 Q1454
# 61720 02475 Q10305
# 61720 69140 Q10305
# 02475 69140 Q10305
# 24583 93339 Q11436
# 24583 79006 Q11436
# 93339 79006 Q11436
# 74490 81543 Q659255
# 92825 09106 Q1246
# 92825 64133 Q1246
# 09106 64133 Q1246
# 21404 35290 Q12837728
# 07357 77218 Q16882643
# 36337 89973 Q2631587
# 72094 05693 Q4801318
# 72217 24374 Q411377
# 53813 81709 Q56121140
# 53813 50446 Q56121140
# 53813 55506 Q56121140
# 81709 50446 Q56121140
# 81709 55506 Q56121140
# 50446 55506 Q56121140
# 43127 10445 Q1041
# 43127 10328 Q1041
# 10445 10328 Q1041
# 32851 02695 Q24232736
# 56448 30332 Q58967
# 33633 63204 Q35760
# 92897 28266 Q2396722
# 54869 04592 Q1794
# 54869 53860 Q1794
# 54869 91437 Q1794
# 54869 26166 Q1794
# 54869 84749 Q1794
# 04592 53860 Q1794
# 04592 91437 Q1794
# 04592 26166 Q1794
# 04592 84749 Q1794
# 53860 91437 Q1794
# 53860 26166 Q1794
# 53860 84749 Q1794
# 91437 26166 Q1794
# 91437 84749 Q1794
# 26166 84749 Q1794
# 10471 77304 Q16882541
# 68947 12045 Q28045604
# 08256 35375 Q14566942
# 08256 05418 Q14566942
# 35375 05418 Q14566942
# 66162 01384 Q37038
# 66162 91589 Q37038
# 01384 91589 Q37038
# 65566 48650 Q461529
# 35201 73756 Q165131
# 65606 88401 Q15406
# 50829 60917 Q10708
# 50829 38128 Q10708
# 60917 38128 Q10708
# 48244 01876 Q573344
# 85133 42606 Q1204831
# 47450 64769 Q42735
# 40759 13107 Q13582719
# 40759 50384 Q13582719
# 13107 50384 Q13582719
# 95136 17768 Q835051
# 60373 52850 Q147934
# 98224 07621 Q220998
# 76044 17011 Q10686
# 76044 72807 Q10686
# 76044 87551 Q10686
# 76044 02663 Q10686
# 17011 72807 Q10686
# 17011 87551 Q10686
# 17011 02663 Q10686
# 72807 87551 Q10686
# 72807 02663 Q10686
# 87551 02663 Q10686
# 00640 64809 Q37572593
# 23869 44162 Q262
# 23869 06206 Q262
# 23869 83262 Q262
# 23869 12878 Q262
# 23869 40876 Q262
# 23869 49093 Q262
# 44162 06206 Q262
# 44162 83262 Q262
# 44162 12878 Q262
# 44162 40876 Q262
# 44162 49093 Q262
# 06206 83262 Q262
# 06206 12878 Q262
# 06206 40876 Q262
# 06206 49093 Q262
# 83262 12878 Q262
# 83262 40876 Q262
# 83262 49093 Q262
# 12878 40876 Q262
# 12878 49093 Q262
# 40876 49093 Q262
# 69502 88760 Q1296
# 69502 65334 Q1296
# 88760 65334 Q1296
# 56904 01144 Q1965
# 26797 24072 Q53130
# 01025 18647 Q7535073
# 10751 78066 Q49221
# 95049 30174 Q8471
# 14707 71956 Q3143131
# 81418 88153 Q6237101
# 47692 59471 Q47284
# 47692 19983 Q47284
# 59471 19983 Q47284
# 85783 90368 Q2319562
# 93677 26326 Q172152
# 51446 43786 Q967453
# 51446 47559 Q967453
# 43786 47559 Q967453
# 37858 35216 Q349
# 97464 10136 Q833032
# 49894 88886 Q13950
# 50698 89478 Q965
# 50698 80062 Q965
# 89478 80062 Q965
# 93489 53788 Q1823966
# 10484 26568 Q7707830
# 28807 78821 Q26883544
# 28807 80593 Q26883544
# 78821 80593 Q26883544
# 56222 73032 Q3064323
# 79895 36665 Q61843
# 62445 74090 Q9626
# 48708 05509 Q836
# 48708 54078 Q836
# 48708 71592 Q836
# 48708 43117 Q836
# 48708 81022 Q836
# 48708 05894 Q836
# 48708 91845 Q836
# 05509 54078 Q836
# 05509 71592 Q836
# 05509 43117 Q836
# 05509 81022 Q836
# 05509 05894 Q836
# 05509 91845 Q836
# 54078 71592 Q836
# 54078 43117 Q836
# 54078 81022 Q836
# 54078 05894 Q836
# 54078 91845 Q836
# 71592 43117 Q836
# 71592 81022 Q836
# 71592 05894 Q836
# 71592 91845 Q836
# 43117 81022 Q836
# 43117 05894 Q836
# 43117 91845 Q836
# 81022 05894 Q836
# 81022 91845 Q836
# 05894 91845 Q836
# 76488 77720 Q1631106
# 31894 99123 Q761
# 31894 59115 Q761
# 99123 59115 Q761
# 65082 57307 Q486329
# 93912 34272 Q815436
# 66209 11178 Q2661464
# 21083 87578 Q131183
# 85947 26771 Q805
# 85947 46721 Q805
# 85947 26551 Q805
# 85947 38585 Q805
# 26771 46721 Q805
# 26771 26551 Q805
# 26771 38585 Q805
# 46721 26551 Q805
# 46721 38585 Q805
# 26551 38585 Q805
# 44562 88323 Q430024
# 96809 59736 Q2656
# 92637 14205 Q12518
# 73965 90931 Q13140900
# 32450 30431 Q25279
# 32450 60216 Q25279
# 30431 60216 Q25279
# 41119 79240 Q52954
# 93028 22650 Q9240
# 96554 53847 Q265
# 96554 17832 Q265
# 96554 55215 Q265
# 53847 17832 Q265
# 53847 55215 Q265
# 17832 55215 Q265
# 16378 11714 Q483639
# 16378 33708 Q483639
# 16378 62918 Q483639
# 11714 33708 Q483639
# 11714 62918 Q483639
# 33708 62918 Q483639
# 51662 98447 Q109535
# 32907 13455 Q792
# 88462 02431 Q6221
# 98025 48625 Q5255905
# 32319 15477 Q713305
# 05067 74296 Q132821
# 05067 77726 Q132821
# 05067 27922 Q132821
# 74296 77726 Q132821
# 74296 27922 Q132821
# 77726 27922 Q132821
# 00801 71061 Q817902
# 66536 48694 Q415588
# 84482 76419 Q8686
# 78763 72396 Q1404472
# 42969 68618 Q11190
# 42969 49139 Q11190
# 68618 49139 Q11190
# 77896 51929 Q482994
# 50474 89157 Q81566
# 01292 98721 Q1191417
# 01292 78996 Q1191417
# 98721 78996 Q1191417
# 41685 16022 Q1046088
# 94644 04820 Q864503
# 94644 02462 Q864503
# 04820 02462 Q864503
# 15245 25221 Q23129
# 76674 34648 Q231312
# 82799 04358 Q13918
# 08274 87562 Q179975
# 36498 87721 Q2827
# 74742 08197 Q5168500
# 50615 18692 Q188
# 50615 49385 Q188
# 50615 78163 Q188
# 18692 49385 Q188
# 18692 78163 Q188
# 49385 78163 Q188
# 82412 92768 Q1054765
# 49468 10253 Q28800549
# 46562 56901 Q7123
# 44734 42131 Q7838
# 44734 98520 Q7838
# 42131 98520 Q7838
# 80803 10319 Q430864
# 54777 72073 Q870449
# 18900 43444 Q48989
# 18197 73232 Q27117926
# 18197 96205 Q27117926
# 73232 96205 Q27117926
# 38037 59046 Q524660
# 56079 11962 Q63070
# 98222 19518 Q174
# 98222 57439 Q174
# 98222 20283 Q174
# 98222 35267 Q174
# 19518 57439 Q174
# 19518 20283 Q174
# 19518 35267 Q174
# 57439 20283 Q174
# 57439 35267 Q174
# 20283 35267 Q174
# 14935 10165 Q150651
# 39923 66081 Q1210
# 53452 12645 Q3846
# 75306 02902 Q900
# 75306 05543 Q900
# 02902 05543 Q900
# 72995 19299 Q2566375
# 89675 93575 Q7026
# 89675 32355 Q7026
# 89675 02569 Q7026
# 93575 32355 Q7026
# 93575 02569 Q7026
# 32355 02569 Q7026
# 09220 73603 Q170433
# 51619 64352 Q100159
# 51619 44303 Q100159
# 64352 44303 Q100159
# 34493 37286 Q42790984
# 22721 33174 Q23999279
# 22721 06942 Q23999279
# 33174 06942 Q23999279
# 15920 02315 Q221
# 15920 09718 Q221
# 15920 80732 Q221
# 02315 09718 Q221
# 02315 80732 Q221
# 09718 80732 Q221
# 30777 79920 Q27061847
# 30777 40043 Q27061847
# 30777 14971 Q27061847
# 79920 40043 Q27061847
# 79920 14971 Q27061847
# 40043 14971 Q27061847
# 30995 53865 Q11220
# 86373 21155 Q8811
# 46385 83600 Q155702
# 92016 53489 Q27079
# 92016 95718 Q27079
# 53489 95718 Q27079
# 07990 86397 Q44426
# 69591 86235 Q192127
# 94509 44574 Q12792
# 57896 89625 Q7184
# 88078 04715 Q1190904
# 31013 87718 Q482
# 31013 88639 Q482
# 87718 88639 Q482
# 51853 82324 Q98
# 51853 49457 Q98
# 51853 22274 Q98
# 51853 80708 Q98
# 51853 20730 Q98
# 51853 30460 Q98
# 82324 49457 Q98
# 82324 22274 Q98
# 82324 80708 Q98
# 82324 20730 Q98
# 82324 30460 Q98
# 49457 22274 Q98
# 49457 80708 Q98
# 49457 20730 Q98
# 49457 30460 Q98
# 22274 80708 Q98
# 22274 20730 Q98
# 22274 30460 Q98
# 80708 20730 Q98
# 80708 30460 Q98
# 20730 30460 Q98
# 85216 09523 Q664
# 85216 95686 Q664
# 85216 16680 Q664
# 09523 95686 Q664
# 09523 16680 Q664
# 95686 16680 Q664
# 76515 80713 Q429220
# 04865 33473 Q23768
# 59611 91729 Q41583
# 72123 41212 Q774
# 72123 33480 Q774
# 72123 90206 Q774
# 72123 54908 Q774
# 41212 33480 Q774
# 41212 90206 Q774
# 41212 54908 Q774
# 33480 90206 Q774
# 33480 54908 Q774
# 90206 54908 Q774
# 99307 15057 Q1075929
# 21831 03481 Q25164
# 21831 87779 Q25164
# 03481 87779 Q25164
# 64063 77503 Q1061108
# 10610 77439 Q182842
# 10610 63261 Q182842
# 77439 63261 Q182842
# 62099 28975 Q7986919
# 63626 80103 Q232358
# 11996 75990 Q27860
# 32513 59098 Q25280
# 62744 99932 Q7603624
# 89772 03331 Q483020
# 19967 14048 Q11299
# 19967 49728 Q11299
# 14048 49728 Q11299
# 09356 74965 Q1479
# 90517 51177 Q34
# 90517 78393 Q34
# 90517 31799 Q34
# 90517 77389 Q34
# 90517 87911 Q34
# 90517 61875 Q34
# 90517 88924 Q34
# 90517 62302 Q34
# 90517 80486 Q34
# 90517 86667 Q34
# 90517 33781 Q34
# 90517 06873 Q34
# 51177 78393 Q34
# 51177 31799 Q34
# 51177 77389 Q34
# 51177 87911 Q34
# 51177 61875 Q34
# 51177 88924 Q34
# 51177 62302 Q34
# 51177 80486 Q34
# 51177 86667 Q34
# 51177 33781 Q34
# 51177 06873 Q34
# 78393 31799 Q34
# 78393 77389 Q34
# 78393 87911 Q34
# 78393 61875 Q34
# 78393 88924 Q34
# 78393 62302 Q34
# 78393 80486 Q34
# 78393 86667 Q34
# 78393 33781 Q34
# 78393 06873 Q34
# 31799 77389 Q34
# 31799 87911 Q34
# 31799 61875 Q34
# 31799 88924 Q34
# 31799 62302 Q34
# 31799 80486 Q34
# 31799 86667 Q34
# 31799 33781 Q34
# 31799 06873 Q34
# 77389 87911 Q34
# 77389 61875 Q34
# 77389 88924 Q34
# 77389 62302 Q34
# 77389 80486 Q34
# 77389 86667 Q34
# 77389 33781 Q34
# 77389 06873 Q34
# 87911 61875 Q34
# 87911 88924 Q34
# 87911 62302 Q34
# 87911 80486 Q34
# 87911 86667 Q34
# 87911 33781 Q34
# 87911 06873 Q34
# 61875 88924 Q34
# 61875 62302 Q34
# 61875 80486 Q34
# 61875 86667 Q34
# 61875 33781 Q34
# 61875 06873 Q34
# 88924 62302 Q34
# 88924 80486 Q34
# 88924 86667 Q34
# 88924 33781 Q34
# 88924 06873 Q34
# 62302 80486 Q34
# 62302 86667 Q34
# 62302 33781 Q34
# 62302 06873 Q34
# 80486 86667 Q34
# 80486 33781 Q34
# 80486 06873 Q34
# 86667 33781 Q34
# 86667 06873 Q34
# 33781 06873 Q34
# 99815 27235 Q161238
# 99815 10828 Q161238
# 27235 10828 Q161238
# 57990 22671 Q6607
# 57990 61220 Q6607
# 22671 61220 Q6607
# 88674 14718 Q750
# 88674 58285 Q750
# 88674 65296 Q750
# 88674 37576 Q750
# 88674 50927 Q750
# 14718 58285 Q750
# 14718 65296 Q750
# 14718 37576 Q750
# 14718 50927 Q750
# 58285 65296 Q750
# 58285 37576 Q750
# 58285 50927 Q750
# 65296 37576 Q750
# 65296 50927 Q750
# 37576 50927 Q750
# 81354 26808 Q1058775
# 68428 68698 Q1572315
# 27341 60559 Q12303
# 56905 73233 Q1711
# 09763 26038 Q50976258
# 18977 23129 Q58680
# 18977 91997 Q58680
# 18977 48782 Q58680
# 23129 91997 Q58680
# 23129 48782 Q58680
# 91997 48782 Q58680
# 45719 08306 Q908
# 45719 90083 Q908
# 08306 90083 Q908
# 62543 67723 Q371522
# 86961 71470 Q365
# 86961 92212 Q365
# 86961 81896 Q365
# 86961 65365 Q365
# 86961 13819 Q365
# 86961 32100 Q365
# 71470 92212 Q365
# 71470 81896 Q365
# 71470 65365 Q365
# 71470 13819 Q365
# 71470 32100 Q365
# 92212 81896 Q365
# 92212 65365 Q365
# 92212 13819 Q365
# 92212 32100 Q365
# 81896 65365 Q365
# 81896 13819 Q365
# 81896 32100 Q365
# 65365 13819 Q365
# 65365 32100 Q365
# 13819 32100 Q365
# 83139 05830 Q7998160
# 07199 66444 Q172
# 07199 46646 Q172
# 07199 78603 Q172
# 07199 57347 Q172
# 66444 46646 Q172
# 66444 78603 Q172
# 66444 57347 Q172
# 46646 78603 Q172
# 46646 57347 Q172
# 78603 57347 Q172
# 75686 91955 Q23109
# 53368 05338 Q789447
# 02031 28509 Q408
# 02031 72462 Q408
# 02031 00848 Q408
# 02031 32310 Q408
# 02031 79826 Q408
# 02031 23094 Q408
# 02031 02028 Q408
# 02031 44344 Q408
# 02031 98488 Q408
# 28509 72462 Q408
# 28509 00848 Q408
# 28509 32310 Q408
# 28509 79826 Q408
# 28509 23094 Q408
# 28509 02028 Q408
# 28509 44344 Q408
# 28509 98488 Q408
# 72462 00848 Q408
# 72462 32310 Q408
# 72462 79826 Q408
# 72462 23094 Q408
# 72462 02028 Q408
# 72462 44344 Q408
# 72462 98488 Q408
# 00848 32310 Q408
# 00848 79826 Q408
# 00848 23094 Q408
# 00848 02028 Q408
# 00848 44344 Q408
# 00848 98488 Q408
# 32310 79826 Q408
# 32310 23094 Q408
# 32310 02028 Q408
# 32310 44344 Q408
# 32310 98488 Q408
# 79826 23094 Q408
# 79826 02028 Q408
# 79826 44344 Q408
# 79826 98488 Q408
# 23094 02028 Q408
# 23094 44344 Q408
# 23094 98488 Q408
# 02028 44344 Q408
# 02028 98488 Q408
# 44344 98488 Q408
# 36217 54235 Q30
# 36217 67798 Q30
# 36217 63958 Q30
# 36217 80266 Q30
# 36217 67842 Q30
# 36217 97297 Q30
# 36217 73186 Q30
# 54235 67798 Q30
# 54235 63958 Q30
# 54235 80266 Q30
# 54235 67842 Q30
# 54235 97297 Q30
# 54235 73186 Q30
# 67798 63958 Q30
# 67798 80266 Q30
# 67798 67842 Q30
# 67798 97297 Q30
# 67798 73186 Q30
# 63958 80266 Q30
# 63958 67842 Q30
# 63958 97297 Q30
# 63958 73186 Q30
# 80266 67842 Q30
# 80266 97297 Q30
# 80266 73186 Q30
# 67842 97297 Q30
# 67842 73186 Q30
# 97297 73186 Q30
# 35593 00766 Q234178
# 35593 67267 Q234178
# 00766 67267 Q234178
# 55679 22538 Q3513566
# 71601 78005 Q47465
# 13154 41286 Q29907
# 39201 85226 Q25933418
# 39201 59201 Q25933418
# 85226 59201 Q25933418
# 75120 53882 Q1612
# 80150 39059 Q16965792
# 60031 73081 Q819
# 60031 55788 Q819
# 73081 55788 Q819
# 36694 07877 Q6166662
# 02284 12898 Q43631
# 25488 34385 Q1945756
# 52893 19718 Q3914
# 47122 70859 Q132510
# 71806 96695 Q3974
# 06255 38445 Q174880
# 28468 40879 Q28640
# 45017 87550 Q540571
# 31824 89585 Q19589
# 31824 58941 Q19589
# 89585 58941 Q19589
# 57059 50214 Q978707
# 57059 13735 Q978707
# 50214 13735 Q978707
# 17852 18864 Q671950
# 07793 20672 Q1722296
# 09114 53901 Q16639072
# 09114 95959 Q16639072
# 53901 95959 Q16639072
# 46573 94402 Q1891
# 46573 87260 Q1891
# 46573 96703 Q1891
# 46573 76241 Q1891
# 94402 87260 Q1891
# 94402 96703 Q1891
# 94402 76241 Q1891
# 87260 96703 Q1891
# 87260 76241 Q1891
# 96703 76241 Q1891
# 84346 59229 Q980
# 84346 98303 Q980
# 84346 48008 Q980
# 84346 08463 Q980
# 59229 98303 Q980
# 59229 48008 Q980
# 59229 08463 Q980
# 98303 48008 Q980
# 98303 08463 Q980
# 48008 08463 Q980
# 67107 63031 Q1674548
# 32989 53062 Q2211
# 32989 78865 Q2211
# 53062 78865 Q2211
# 47080 44753 Q1498
# 47080 37693 Q1498
# 44753 37693 Q1498
# 25572 28128 Q13830
# 60812 09882 Q13590141
# 30620 24183 Q30329987
# 08677 28405 Q139564
# 13060 72427 Q155
# 13060 16187 Q155
# 13060 13682 Q155
# 13060 10600 Q155
# 13060 63276 Q155
# 13060 47331 Q155
# 13060 44501 Q155
# 13060 57151 Q155
# 13060 90189 Q155
# 13060 98294 Q155
# 13060 84602 Q155
# 13060 53496 Q155
# 13060 74966 Q155
# 13060 52698 Q155
# 13060 69258 Q155
# 13060 35501 Q155
# 72427 16187 Q155
# 72427 13682 Q155
# 72427 10600 Q155
# 72427 63276 Q155
# 72427 47331 Q155
# 72427 44501 Q155
# 72427 57151 Q155
# 72427 90189 Q155
# 72427 98294 Q155
# 72427 84602 Q155
# 72427 53496 Q155
# 72427 74966 Q155
# 72427 52698 Q155
# 72427 69258 Q155
# 72427 35501 Q155
# 16187 13682 Q155
# 16187 10600 Q155
# 16187 63276 Q155
# 16187 47331 Q155
# 16187 44501 Q155
# 16187 57151 Q155
# 16187 90189 Q155
# 16187 98294 Q155
# 16187 84602 Q155
# 16187 53496 Q155
# 16187 74966 Q155
# 16187 52698 Q155
# 16187 69258 Q155
# 16187 35501 Q155
# 13682 10600 Q155
# 13682 63276 Q155
# 13682 47331 Q155
# 13682 44501 Q155
# 13682 57151 Q155
# 13682 90189 Q155
# 13682 98294 Q155
# 13682 84602 Q155
# 13682 53496 Q155
# 13682 74966 Q155
# 13682 52698 Q155
# 13682 69258 Q155
# 13682 35501 Q155
# 10600 63276 Q155
# 10600 47331 Q155
# 10600 44501 Q155
# 10600 57151 Q155
# 10600 90189 Q155
# 10600 98294 Q155
# 10600 84602 Q155
# 10600 53496 Q155
# 10600 74966 Q155
# 10600 52698 Q155
# 10600 69258 Q155
# 10600 35501 Q155
# 63276 47331 Q155
# 63276 44501 Q155
# 63276 57151 Q155
# 63276 90189 Q155
# 63276 98294 Q155
# 63276 84602 Q155
# 63276 53496 Q155
# 63276 74966 Q155
# 63276 52698 Q155
# 63276 69258 Q155
# 63276 35501 Q155
# 47331 44501 Q155
# 47331 57151 Q155
# 47331 90189 Q155
# 47331 98294 Q155
# 47331 84602 Q155
# 47331 53496 Q155
# 47331 74966 Q155
# 47331 52698 Q155
# 47331 69258 Q155
# 47331 35501 Q155
# 44501 57151 Q155
# 44501 90189 Q155
# 44501 98294 Q155
# 44501 84602 Q155
# 44501 53496 Q155
# 44501 74966 Q155
# 44501 52698 Q155
# 44501 69258 Q155
# 44501 35501 Q155
# 57151 90189 Q155
# 57151 98294 Q155
# 57151 84602 Q155
# 57151 53496 Q155
# 57151 74966 Q155
# 57151 52698 Q155
# 57151 69258 Q155
# 57151 35501 Q155
# 90189 98294 Q155
# 90189 84602 Q155
# 90189 53496 Q155
# 90189 74966 Q155
# 90189 52698 Q155
# 90189 69258 Q155
# 90189 35501 Q155
# 98294 84602 Q155
# 98294 53496 Q155
# 98294 74966 Q155
# 98294 52698 Q155
# 98294 69258 Q155
# 98294 35501 Q155
# 84602 53496 Q155
# 84602 74966 Q155
# 84602 52698 Q155
# 84602 69258 Q155
# 84602 35501 Q155
# 53496 74966 Q155
# 53496 52698 Q155
# 53496 69258 Q155
# 53496 35501 Q155
# 74966 52698 Q155
# 74966 69258 Q155
# 74966 35501 Q155
# 52698 69258 Q155
# 52698 35501 Q155
# 69258 35501 Q155
# 53275 82102 Q12589
# 53275 05016 Q12589
# 82102 05016 Q12589
# 53908 73825 Q4699353
# 85899 19591 Q129352
# 76836 59126 Q956
# 76836 75462 Q956
# 76836 95148 Q956
# 76836 01220 Q956
# 59126 75462 Q956
# 59126 95148 Q956
# 59126 01220 Q956
# 75462 95148 Q956
# 75462 01220 Q956
# 95148 01220 Q956
# 22484 51226 Q68283
# 44122 54059 Q15789
# 37141 70950 Q66171
# 00311 80195 Q3951435
# 55745 90242 Q64
# 55745 59816 Q64
# 55745 24697 Q64
# 55745 30047 Q64
# 55745 40520 Q64
# 55745 21716 Q64
# 90242 59816 Q64
# 90242 24697 Q64
# 90242 30047 Q64
# 90242 40520 Q64
# 90242 21716 Q64
# 59816 24697 Q64
# 59816 30047 Q64
# 59816 40520 Q64
# 59816 21716 Q64
# 24697 30047 Q64
# 24697 40520 Q64
# 24697 21716 Q64
# 30047 40520 Q64
# 30047 21716 Q64
# 40520 21716 Q64
# 97716 14915 Q187223
# 61570 39882 Q128239
# 83353 13704 Q1748
# 83353 09739 Q1748
# 13704 09739 Q1748
# 68263 52638 Q599435
# 89484 53715 Q44749
# 13016 70162 Q10514
# 58486 16718 Q321197
# 71328 61725 Q496351
# 41956 66007 Q3505712
# 63903 37899 Q29548
# 36420 04630 Q31
# 36420 32128 Q31
# 36420 08026 Q31
# 36420 56566 Q31
# 36420 61348 Q31
# 36420 54306 Q31
# 36420 58293 Q31
# 36420 76492 Q31
# 36420 08618 Q31
# 36420 97051 Q31
# 04630 32128 Q31
# 04630 08026 Q31
# 04630 56566 Q31
# 04630 61348 Q31
# 04630 54306 Q31
# 04630 58293 Q31
# 04630 76492 Q31
# 04630 08618 Q31
# 04630 97051 Q31
# 32128 08026 Q31
# 32128 56566 Q31
# 32128 61348 Q31
# 32128 54306 Q31
# 32128 58293 Q31
# 32128 76492 Q31
# 32128 08618 Q31
# 32128 97051 Q31
# 08026 56566 Q31
# 08026 61348 Q31
# 08026 54306 Q31
# 08026 58293 Q31
# 08026 76492 Q31
# 08026 08618 Q31
# 08026 97051 Q31
# 56566 61348 Q31
# 56566 54306 Q31
# 56566 58293 Q31
# 56566 76492 Q31
# 56566 08618 Q31
# 56566 97051 Q31
# 61348 54306 Q31
# 61348 58293 Q31
# 61348 76492 Q31
# 61348 08618 Q31
# 61348 97051 Q31
# 54306 58293 Q31
# 54306 76492 Q31
# 54306 08618 Q31
# 54306 97051 Q31
# 58293 76492 Q31
# 58293 08618 Q31
# 58293 97051 Q31
# 76492 08618 Q31
# 76492 97051 Q31
# 08618 97051 Q31
# 68870 05259 Q363962
# 21314 70618 Q7876033
# 24265 31646 Q948657
# 20104 88663 Q7377
# 20104 08717 Q7377
# 88663 08717 Q7377
# 24835 41577 Q105844
# 22738 71276 Q6122670
# 32942 78387 Q132714
# 94946 49287 Q1204
# 94946 34583 Q1204
# 49287 34583 Q1204
# 33379 46973 Q1284408
# 17636 44168 Q520119
# 87282 90784 Q1809316
# 79133 56714 Q183
# 79133 88792 Q183
# 79133 95310 Q183
# 79133 35422 Q183
# 79133 66308 Q183
# 79133 94154 Q183
# 79133 38515 Q183
# 79133 37596 Q183
# 56714 88792 Q183
# 56714 95310 Q183
# 56714 35422 Q183
# 56714 66308 Q183
# 56714 94154 Q183
# 56714 38515 Q183
# 56714 37596 Q183
# 88792 95310 Q183
# 88792 35422 Q183
# 88792 66308 Q183
# 88792 94154 Q183
# 88792 38515 Q183
# 88792 37596 Q183
# 95310 35422 Q183
# 95310 66308 Q183
# 95310 94154 Q183
# 95310 38515 Q183
# 95310 37596 Q183
# 35422 66308 Q183
# 35422 94154 Q183
# 35422 38515 Q183
# 35422 37596 Q183
# 66308 94154 Q183
# 66308 38515 Q183
# 66308 37596 Q183
# 94154 38515 Q183
# 94154 37596 Q183
# 38515 37596 Q183
# 73002 24570 Q5789078
# 19186 10859 Q24354
# 25443 25360 Q382065
# 61955 30708 Q131186
# 34131 26945 Q276099
# 05678 74245 Q2757508
# 45848 11362 Q320950
# 90032 77969 Q648
# 90032 95582 Q648
# 77969 95582 Q648
# 24644 40373 Q2767140
# 85391 25639 Q597476
# 61892 81650 Q7205
# 61892 25382 Q7205
# 81650 25382 Q7205
# 45724 00262 Q21201
# 45724 43963 Q21201
# 00262 43963 Q21201
# 21991 31495 Q97
# 21991 99867 Q97
# 21991 61141 Q97
# 31495 99867 Q97
# 31495 61141 Q97
# 99867 61141 Q97
# 46095 26009 Q54149
# 05422 62819 Q19000661
# 05422 59333 Q19000661
# 62819 59333 Q19000661
# 60144 22994 Q1622083
# 44820 81722 Q418369
# 83058 85264 Q134147
# 49617 21496 Q720377
# 34688 18483 Q53819
# 47561 19034 Q7050
# 97236 86832 Q907311
# 95342 59598 Q738775
# 42812 80595 Q4734924
# 55268 93991 Q11254401
# 82174 91087 Q31467408
# 84849 70406 Q12753
# 11246 93647 Q64027
# 48265 89474 Q381934
# 01790 67491 Q37
# 01790 37726 Q37
# 01790 51470 Q37
# 01790 38035 Q37
# 01790 21277 Q37
# 67491 37726 Q37
# 67491 51470 Q37
# 67491 38035 Q37
# 67491 21277 Q37
# 37726 51470 Q37
# 37726 38035 Q37
# 37726 21277 Q37
# 51470 38035 Q37
# 51470 21277 Q37
# 38035 21277 Q37
# 64262 45193 Q36188
# 02416 76962 Q204623
# 58350 13613 Q623099
# 83128 05775 Q36091
# 83128 59943 Q36091
# 05775 59943 Q36091
# 89558 82900 Q574
# 60396 43472 Q9061
# 60396 59751 Q9061
# 43472 59751 Q9061
# 64800 06516 Q2214
# 43582 14336 Q199602
# 50867 25381 Q4176708
# 06965 11468 Q408524
# 87112 48475 Q36
# 87112 35052 Q36
# 87112 02908 Q36
# 87112 38966 Q36
# 87112 88776 Q36
# 87112 27309 Q36
# 48475 35052 Q36
# 48475 02908 Q36
# 48475 38966 Q36
# 48475 88776 Q36
# 48475 27309 Q36
# 35052 02908 Q36
# 35052 38966 Q36
# 35052 88776 Q36
# 35052 27309 Q36
# 02908 38966 Q36
# 02908 88776 Q36
# 02908 27309 Q36
# 38966 88776 Q36
# 38966 27309 Q36
# 88776 27309 Q36
# 40307 28026 Q448807
# 41979 71921 Q210205
# 79135 91946 Q7397
# 08679 09792 Q1201513
# 02490 19004 Q638608
# 02490 23375 Q638608
# 02490 64603 Q638608
# 19004 23375 Q638608
# 19004 64603 Q638608
# 23375 64603 Q638608
# 62065 27284 Q1044693
# 01397 98957 Q11943008
# 17896 53436 Q4545331
# 95218 59138 Q1021290
# 47176 09863 Q7328910
# 53766 70574 Q3734691
# 07904 98597 Q7320948
# 02875 12477 Q979914
# 13134 98526 Q12667986
# 85900 47930 Q35715
# 63096 96667 Q49989
# 40562 23565 Q1006
# 40562 61020 Q1006
# 40562 44473 Q1006
# 23565 61020 Q1006
# 23565 44473 Q1006
# 61020 44473 Q1006
# 71883 46019 Q1439
# 87014 91152 Q193190
# 93269 32729 Q356311
# 58890 58137 Q55410
# 97955 60636 Q857667
# 97955 52627 Q857667
# 60636 52627 Q857667
# 75181 88038 Q1770313
# 11517 76618 Q246887
# 37987 49845 Q845623
# 33928 27023 Q102911
# 17796 11896 Q1372614
# 26142 72259 Q15332542
# 92072 86904 Q1449
# 92072 67032 Q1449
# 92072 02353 Q1449
# 86904 67032 Q1449
# 86904 02353 Q1449
# 67032 02353 Q1449
# 97012 75002 Q209142
# 78644 14870 Q9058
# 78644 66327 Q9058
# 14870 66327 Q9058
# 32394 79660 Q42308
# 32394 03451 Q42308
# 79660 03451 Q42308
# 75321 28394 Q398
# 59468 20170 Q20061641
# 97497 80992 Q716
# 45421 28259 Q16335075
# 95984 95901 Q155993
# 24042 05461 Q686301
# 63870 91402 Q208713
# 23397 80063 Q3318733
# 43403 52330 Q132241
# 90948 10890 Q808845
# 82879 65747 Q18
# 75285 24981 Q8682
# 75285 21291 Q8682
# 75285 16440 Q8682
# 24981 21291 Q8682
# 24981 16440 Q8682
# 21291 16440 Q8682
# 65193 08357 Q18661
# 65193 26318 Q18661
# 08357 26318 Q18661
# 51300 10698 Q17612278
# 40700 43702 Q7338273
# 04207 51247 Q1018341
# 24021 73136 Q667276
# 24021 49234 Q667276
# 73136 49234 Q667276
# 88748 10605 Q14540
# 59332 75128 Q68
# 49865 03396 Q125191
# 49865 94486 Q125191
# 49865 32558 Q125191
# 49865 20985 Q125191
# 03396 94486 Q125191
# 03396 32558 Q125191
# 03396 20985 Q125191
# 94486 32558 Q125191
# 94486 20985 Q125191
# 32558 20985 Q125191
# 39060 00561 Q683
# 39060 52559 Q683
# 00561 52559 Q683
# 51049 20768 Q1156
# 51049 77174 Q1156
# 51049 43369 Q1156
# 51049 61664 Q1156
# 20768 77174 Q1156
# 20768 43369 Q1156
# 20768 61664 Q1156
# 77174 43369 Q1156
# 77174 61664 Q1156
# 43369 61664 Q1156
# 19773 97439 Q152574
# 38710 06693 Q816096
# 22119 46763 Q5110676
# 68237 26731 Q3129
# 70602 32980 Q28
# 70602 65504 Q28
# 70602 49611 Q28
# 70602 36397 Q28
# 70602 12222 Q28
# 70602 09362 Q28
# 70602 93797 Q28
# 70602 01665 Q28
# 32980 65504 Q28
# 32980 49611 Q28
# 32980 36397 Q28
# 32980 12222 Q28
# 32980 09362 Q28
# 32980 93797 Q28
# 32980 01665 Q28
# 65504 49611 Q28
# 65504 36397 Q28
# 65504 12222 Q28
# 65504 09362 Q28
# 65504 93797 Q28
# 65504 01665 Q28
# 49611 36397 Q28
# 49611 12222 Q28
# 49611 09362 Q28
# 49611 93797 Q28
# 49611 01665 Q28
# 36397 12222 Q28
# 36397 09362 Q28
# 36397 93797 Q28
# 36397 01665 Q28
# 12222 09362 Q28
# 12222 93797 Q28
# 12222 01665 Q28
# 09362 93797 Q28
# 09362 01665 Q28
# 93797 01665 Q28
# 22503 02950 Q155769
# 75779 95530 Q28025049
# 37654 59752 Q819170
# 19550 39838 Q9772
# 39084 59248 Q2065736
# 80883 43926 Q2188329
# 28127 41609 Q9199
# 92237 41696 Q2795
# 35663 32631 Q33788
# 80902 44814 Q1908174
# 87196 41063 Q173219
# 28384 06140 Q148
# 28384 46870 Q148
# 28384 67435 Q148
# 28384 89721 Q148
# 06140 46870 Q148
# 06140 67435 Q148
# 06140 89721 Q148
# 46870 67435 Q148
# 46870 89721 Q148
# 67435 89721 Q148
# 35177 78982 Q28513
# 78766 23844 Q43235
# 65233 30861 Q97074513
# 25103 86158 Q47896
# 90510 17875 Q8765
# 69593 27936 Q211830
# 96661 37660 Q393
# 98914 57433 Q48837
# 42213 35325 Q2536016
# 01279 63698 Q143263
# 72764 67142 Q945
# 72764 17505 Q945
# 67142 17505 Q945
# 71551 09660 Q12542
# 89746 10575 Q4834543
# 36419 75900 Q1072012
# 51279 13288 Q2322256
# 93452 83750 Q108723
# 15295 95507 Q10002
# 15295 50890 Q10002
# 95507 50890 Q10002
# 45026 54186 Q2014
# 48376 23541 Q900424
# 90651 36652 Q482919
# 67592 40132 Q15045403
# 30093 49708 Q50429823
# 55275 29054 Q6877320
# 59933 58760 Q690645
# 04723 45224 Q56061
# 04723 94398 Q56061
# 45224 94398 Q56061
# 33726 23843 Q211457
# 48458 13696 Q636910
# 72511 74894 Q492467
# 00177 32741 Q18125
# 00177 30624 Q18125
# 00177 81069 Q18125
# 32741 30624 Q18125
# 32741 81069 Q18125
# 30624 81069 Q18125
# 10740 95835 Q1455600
# 57633 29780 Q928
# 57633 85466 Q928
# 57633 30117 Q928
# 57633 02979 Q928
# 57633 13583 Q928
# 29780 85466 Q928
# 29780 30117 Q928
# 29780 02979 Q928
# 29780 13583 Q928
# 85466 30117 Q928
# 85466 02979 Q928
# 85466 13583 Q928
# 30117 02979 Q928
# 30117 13583 Q928
# 02979 13583 Q928
# 59803 70418 Q9176
# 59803 67530 Q9176
# 70418 67530 Q9176
# 78038 41218 Q13521
# 89795 53624 Q1268871
# 61285 23648 Q12236
# 61285 51380 Q12236
# 23648 51380 Q12236
# 58705 90415 Q47001778
# 89506 51319 Q5429075
# 32656 78275 Q443540
# 67290 88923 Q214
# 67290 53673 Q214
# 67290 21172 Q214
# 88923 53673 Q214
# 88923 21172 Q214
# 53673 21172 Q214
# ...
# 12946 00658 Q15911
# 51739 48144 Q128446
# 95320 13841 Q557141
# 95320 13477 Q557141
# 13841 13477 Q557141
# 40810 33695 Q23156
# 32342 00668 Q11564852
# 90919 89609 Q502125
# 78956 50841 Q272714
# 10384 58132 Q538101
# 21146 46501 Q954611
# 78120 33622 Q186702
# 78120 41859 Q186702
# 33622 41859 Q186702
# 86141 74836 Q470232
# 75715 02270 Q3589615
# 76578 30863 Q713165
# 86740 39426 Q3151727
# 63735 75256 Q1356743
# 28928 80530 Q102365
# 07983 82235 Q1661583
# 36581 29375 Q289826
# 70641 89537 Q3851308
# 02591 11308 Q1032483
# 68297 65975 Q183048
# 75240 78406 Q6905328
# 62725 24475 Q3550
# 65838 80610 Q4881210
# 82754 76584 Q15635
# 72761 28368 Q194052
# 27356 72341 Q154498
# 55250 13483 Q26206919
# 55250 88139 Q26206919
# 13483 88139 Q26206919
# 09529 60037 Q734
# 30257 48077 Q1489002
# 66693 88795 Q180614
# 16355 57102 Q922989
# 82131 73852 Q800
# 89602 22045 Q889
# 89602 54770 Q889
# 22045 54770 Q889
# 72065 89639 Q4916
# 44374 27286 Q3328774
# 73768 62982 Q194422
# 16973 83075 Q759482
# 03930 89529 Q5092
# 42447 18323 Q17636497
# 45986 82364 Q7414
# 64864 93266 Q392429
# 98280 34379 Q112115877
# 50565 71543 Q850385
# 36783 59408 Q2485448
# 90350 10812 Q2925701
# 55916 28783 Q1781513
# 76892 73502 Q29959101
# 11388 61472 Q286022
# 31846 31768 Q473203
# 66517 86855 Q5509000
# 04019 83231 Q156
# 61548 46548 Q7283
# 63648 39677 Q17473716
# 63648 62258 Q17473716
# 39677 62258 Q17473716
# 23256 60772 Q271659
# 21771 33329 Q414219
# 05879 48201 Q244324
# 39597 03547 Q3270632
# 05719 50354 Q643
# 87552 96070 Q1717246
# 42708 81694 Q205842
# 89096 63646 Q1158317
# 57403 42102 Q83891
# 55753 11516 Q1231361
# 58346 68840 Q6156918
# 64594 10543 Q906569
# 56642 97212 Q1269192
# 56642 90692 Q1269192
# 97212 90692 Q1269192
# 58316 17255 Q958822
# 36711 90532 Q7161092
# 28442 75098 Q63061514
# 11672 46210 Q4628
# 02690 94574 Q956604
# 96217 71453 Q218805
# 50456 25779 Q1201549
# 85122 25711 Q1028023
# 00518 61584 Q924078
# 89561 14002 Q481277
# 17587 66505 Q1622217
# 70328 24276 Q912
# 30631 42753 Q42000
# 30631 78745 Q42000
# 42753 78745 Q42000
# 11300 29032 Q852584
# 77006 82501 Q15922
# 36144 18556 Q132397
# 39475 88772 Q796
# 39475 55252 Q796
# 88772 55252 Q796
# 86922 40546 Q7162871
# 42387 85480 Q179232
# 42387 04777 Q179232
# 85480 04777 Q179232
# 99154 69427 Q11633
# 99154 66277 Q11633
# 69427 66277 Q11633
# 96501 73873 Q7913
# 20861 99579 Q11006
# 69532 24290 Q149836
# 95822 81020 Q12439
# 95822 24437 Q12439
# 81020 24437 Q12439
# 92353 48158 Q902171
# 81313 68030 Q169492
# 34312 91070 Q28528560
# 67696 70530 Q36406
# 44670 61771 Q846570
# 07787 68450 Q422252
# 03825 43718 Q1459037
# 08678 36953 Q5654075
# 50042 39652 Q153616
# 44335 54479 Q26213387
# 13328 53544 Q847546
# 67748 50882 Q1018418
# 51960 14825 Q652
# 06766 13113 Q1218
# 06766 48947 Q1218
# 06766 26574 Q1218
# 13113 48947 Q1218
# 13113 26574 Q1218
# 48947 26574 Q1218
# 65828 44604 Q16871185
# 86847 63990 Q147388
# 39721 48955 Q3490894
# 95090 73747 Q3314483
# 36949 19858 Q17711593
# 59891 84808 Q76206398
# 86320 36925 Q671288
# 06723 15158 Q80791
# 44914 77283 Q402971
# 44461 74436 Q4948
# 68852 27843 Q4017991
# 38557 97769 Q9067
# 16053 60160 Q494702
# 42942 53572 Q106096790
# 98924 18018 Q30588142
# 20194 06080 Q8429
# 89302 71565 Q888024
# 12965 25518 Q643338
# 44175 53066 Q14437811
# 21419 80064 Q856234
# 19743 68911 Q510692
# 93348 18524 Q1279917
# 99419 90898 Q1546
# 98758 54911 Q276
# 78117 67940 Q1352
# 88115 67726 Q80966
# 91881 32201 Q538
# 30933 31583 Q816
# 27179 85527 Q190002
# 90272 19703 Q441
# 65255 98696 Q185246
# 58564 00647 Q1577547
# 73924 43789 Q157575
# 72681 41641 Q1550276
# 59590 41248 Q207095
# 02949 41351 Q57081670
# 31087 76818 Q1538543
# 02108 61597 Q3764242
# 41256 75584 Q11573099
# 98513 94001 Q1840844
# 72338 83889 Q19921515
# 94358 84143 Q3157429
# 57666 82608 Q38511
# 57666 22254 Q38511
# 82608 22254 Q38511
# 93403 86460 Q1682809
# 94449 07156 Q826561
# 99129 94007 Q29602351
# 47499 52808 Q1142082
# 39921 33095 Q9322
# 37519 43149 Q518423
# 08046 57053 Q664341
# 75739 73853 Q223911
# 96426 42057 Q922529
# 90332 57078 Q70972
# 90332 46218 Q70972
# 90332 50977 Q70972
# 90332 56891 Q70972
# 57078 46218 Q70972
# 57078 50977 Q70972
# 57078 56891 Q70972
# 46218 50977 Q70972
# 46218 56891 Q70972
# 50977 56891 Q70972
# 54405 37598 Q126269
# 46619 24220 Q192890
# 84247 12957 Q1425428
# 03925 79462 Q27175
# 27895 56562 Q327223
# 19306 88819 Q816536
# 03171 92845 Q3353
# 78895 77706 Q15726460
# 17529 86890 Q56760322
# 17529 43112 Q56760322
# 86890 43112 Q56760322
# 19652 23406 Q455971
# 41326 68092 Q64909968
# 44655 24608 Q99937
# 07308 22063 Q1959511
# 71179 52407 Q611217
# 83151 30977 Q1384984
# 79748 24746 Q524096
# 89755 85403 Q779
# 49324 07984 Q94084
# 43905 62421 Q79848
# 79530 37528 Q13362
# 41780 72573 Q189125
# 02580 15149 Q917808
# 17433 42499 Q7983490
# 06762 61426 Q1368271
# 34787 03379 Q212624
# 82919 45691 Q603733
# 66275 68159 Q42591
# 07843 42721 Q61161
# 51425 53280 Q12236035
# 58297 88355 Q3117
# 55164 29431 Q29438120
# 66172 51355 Q41211
# 66172 25172 Q41211
# 51355 25172 Q41211
# 20530 64551 Q65948724
# 36514 68816 Q161054
# 06057 45104 Q4512
# 39189 87388 Q192869
# 35368 18847 Q586895
# 01684 64098 Q1071052
# 81035 94917 Q664881
# 13128 85722 Q39809
# 51776 85393 Q58976
# 51776 99378 Q58976
# 85393 99378 Q58976
# 49374 58235 Q136851
# 08654 09145 Q133247
# 87205 71419 Q877897
# 15573 66168 Q188712
# 15573 65601 Q188712
# 66168 65601 Q188712
# 17491 34366 Q193563
# 76358 05896 Q904472
# 45542 50655 Q175081
# 00623 59485 Q16363
# 00552 92656 Q49227
# 00552 17418 Q49227
# 92656 17418 Q49227
# 13617 07980 Q13955
# 86985 36251 Q2480355
# 84952 63059 Q60979085
# 85770 54379 Q19558910
# 21228 75248 Q5354210
# 94134 49897 Q35222
# 93592 41456 Q5801919
# 19009 82909 Q336735
# 13400 10842 Q86020021
# 93241 29182 Q16201761
# 33132 43165 Q235
# 33132 24045 Q235
# 33132 75716 Q235
# 33132 91967 Q235
# 43165 24045 Q235
# 43165 75716 Q235
# 43165 91967 Q235
# 24045 75716 Q235
# 24045 91967 Q235
# 75716 91967 Q235
# 76471 11096 Q42887
# 44255 63091 Q3806
# 66043 89722 Q5252594
# 59775 53524 Q192904
# 57400 06767 Q363956
# 31942 64438 Q95977692
# 66026 16558 Q663
# 69369 80555 Q49012
# 15240 99265 Q1361
# 15240 62999 Q1361
# 99265 62999 Q1361
# 36817 79590 Q15945069
# 09934 64612 Q24639
# 99573 75867 Q945019
# 00841 79305 Q14916
# 94022 32346 Q985755
# 26042 22020 Q62
# 57336 51002 Q13646
# 78635 39548 Q47883
# 16661 33357 Q42810
# 59061 96823 Q11708
# 15192 00175 Q11420
# 15192 34296 Q11420
# 00175 34296 Q11420
# 71431 42740 Q340195
# 90343 34727 Q35014
# 55644 85340 Q278221
# 55644 75498 Q278221
# 85340 75498 Q278221
# 25783 66611 Q128306
# 72959 39265 Q459090
# 50550 94897 Q208594
# 06496 78319 Q522424
# 50260 75682 Q25285
# 77873 57741 Q20003567
# 40067 30407 Q7108
# 79066 71226 Q1067547
# 15255 05244 Q27407
# 04270 32952 Q219626
# 67601 71699 Q1601762
# 29207 25720 Q3145155
# 30207 77664 Q1054718
# 30207 83172 Q1054718
# 77664 83172 Q1054718
# 53991 73274 Q83
# 62179 26086 Q169180
# 06286 87044 Q12174
# 06286 98114 Q12174
# 87044 98114 Q12174
# 62615 76735 Q214178
# 51502 38596 Q99654400
# 27195 35435 Q24862
# 27195 90379 Q24862
# 27195 23472 Q24862
# 35435 90379 Q24862
# 35435 23472 Q24862
# 90379 23472 Q24862
# 92387 13504 Q1280670
# 97136 02832 Q10914562
# 98438 83227 Q241
# 98438 14464 Q241
# 83227 14464 Q241
# 61636 05257 Q117666
# 61636 02190 Q117666
# 05257 02190 Q117666
# 84010 37895 Q13553722
# 84653 22561 Q7960909
# 57620 51188 Q369190
# 53802 00776 Q2437296
# 41576 69509 Q130321
# 19493 77855 Q736742
# 03609 30552 Q906512
# 32022 93533 Q1395430
# 41566 52567 Q18234383
# 41566 89195 Q18234383
# 52567 89195 Q18234383
# 51157 85052 Q546
# 17883 83340 Q7951979
# 98898 74087 Q28061729
# 99400 87307 Q1186
# 03562 83112 Q135265
# 52216 05523 Q20726741
# 03228 57531 Q26398
# 77473 20659 Q26540
# 38141 20983 Q7895977
# 38517 67528 Q169889
# 82687 62495 Q7243
# 53022 56115 Q524894
# 11792 59536 Q499588
# 30058 17860 Q187791
# 26091 17996 Q79015
# 44085 52917 Q4881153
# 80740 52994 Q3116531
# 69731 16649 Q2005
# 22885 05028 Q415336
# 10399 55102 Q2117903
# 85207 69218 Q49266
# 45933 88170 Q174193
# 64935 03332 Q23086
# 64935 68239 Q23086
# 03332 68239 Q23086
# 71962 39638 Q1693
# 84286 54662 Q15228723
# 35795 01505 Q2756484
# 39280 37323 Q15
# 39280 45266 Q15
# 37323 45266 Q15
# 78605 94156 Q457167
# 79009 13944 Q16884844
# 32093 54332 Q9655
# 38116 51431 Q83178
# 27812 17850 Q203509
# 20376 30615 Q20977882
# 92974 36829 Q3077308
# 86180 71487 Q8575586
# 85943 53591 Q1237385
# 03158 97257 Q122575
# 62509 83710 Q146246
# 72158 19952 Q2007778
# 23634 55227 Q2743
# 02684 75295 Q504768
# 22752 56824 Q14314
# 08018 19424 Q110145
# 71240 28762 Q49084
# 54824 05724 Q5891
# 54824 98310 Q5891
# 54824 78025 Q5891
# 05724 98310 Q5891
# 05724 78025 Q5891
# 98310 78025 Q5891
# 42012 76065 Q111901161
# 57972 07562 Q7896565
# 58580 92981 Q8345
# 37118 81446 Q495786
# 35592 38570 Q1045828
# 06353 51795 Q46934
# 63130 60529 Q1070333
# 16774 75642 Q22073936
# 11804 88840 Q1754
# 11804 05108 Q1754
# 88840 05108 Q1754
# 43727 97895 Q122809699
# 44599 42473 Q82664
# 02774 39562 Q18182719
# 66886 00433 Q485294
# 09661 04947 Q75809
# 09661 84839 Q75809
# 04947 84839 Q75809
# 71617 23032 Q1420038
# 55304 95279 Q752129
# 19230 56741 Q18221758
# 45733 18271 Q19453
# 73962 32168 Q3766
# 50818 08321 Q684783
# 73612 52683 Q6859396
# 56488 89693 Q203443
# 42643 33436 Q1818899
# 66373 65628 Q204920
# 92052 35138 Q14960
# 76966 83036 Q534458
# 49521 67610 Q169523
# 39371 03183 Q3788629
# 93381 51048 Q1310
# 93381 47823 Q1310
# 51048 47823 Q1310
# 40671 55147 Q929045
# 40671 30584 Q929045
# 55147 30584 Q929045
# 46839 14072 Q13379
# 72426 43832 Q752719
# 74187 93181 Q1518804
# 19361 96549 Q3151718
# 39896 05525 Q3519
# 14234 04178 Q27881556
# 19273 06267 Q1340307
# 57381 94121 Q50638551
# 02330 54941 Q190088
# 66114 02123 Q29520
# 63145 84362 Q152171
# 02498 99667 Q182060
# 51107 63831 Q309388
# 99362 86845 Q184194
# 21027 61556 Q1868482
# 46725 37985 Q20492
# 26526 27387 Q16861277
# 36973 55876 Q10027
# 23528 96243 Q1044186
# 99628 05639 Q18290535
# 48100 58126 Q2716043
# 00507 41671 Q2298644
# 11069 56573 Q6157049
# 36009 62602 Q169977
# 91848 32701 Q2261276
# 52708 63844 Q1125958
# 76105 52417 Q188740
# 76105 07763 Q188740
# 52417 07763 Q188740
# 41523 30925 Q3329619
# 46205 48377 Q22930465
# 84340 69952 Q233
# 88628 55803 Q10907979
# 75277 46449 Q270794
# 46799 96607 Q1138524
# 86713 80590 Q1737513
# 71758 25271 Q275001
# 27891 52939 Q207977
# 88368 98001 Q9396355
# 89569 52336 Q6064625
# 97172 96086 Q40089
# 69074 64462 Q231019
# 47933 44123 Q168456
# 47933 25312 Q168456
# 44123 25312 Q168456
# 96761 67111 Q150
# 96761 29310 Q150
# 96761 15612 Q150
# 96761 05396 Q150
# 67111 29310 Q150
# 67111 15612 Q150
# 67111 05396 Q150
# 29310 15612 Q150
# 29310 05396 Q150
# 15612 05396 Q150
# 56850 70936 Q184224
# 94340 71478 Q8752
# 21609 09493 Q19478619
# 35025 64362 Q723682
# 98193 50497 Q86446
# 35128 09992 Q55408
# 17493 39243 Q7863800
# 42355 88417 Q12796
# 81959 38033 Q1225
# 82200 13146 Q7075
# 82200 27416 Q7075
# 13146 27416 Q7075
# 40920 41337 Q3415
# 90710 17774 Q695
# 01046 07066 Q66889825
# 25347 52607 Q25302
# 38906 59348 Q2843
# 69723 61453 Q484847
# 97760 58794 Q212
# 97760 61614 Q212
# 97760 84740 Q212
# 58794 61614 Q212
# 58794 84740 Q212
# 61614 84740 Q212
# 53268 40748 Q711123
# 95918 76535 Q6939
# 81544 98688 Q6473911
# 90712 73527 Q830894
# 84367 30019 Q21484813
# 96771 32446 Q8479
# 99391 79366 Q636120
# 97214 58502 Q27116
# 43715 56794 Q811
# 12406 73714 Q234213
# 20267 57748 Q19892
# 48838 80652 Q21758669
# 40202 67265 Q36869506
# 07615 36372 Q6157304
# 65423 46627 Q43196
# 43502 12883 Q23070
# 19765 80040 Q5806
# 27449 04993 Q49210
# 65636 46587 Q1524
# 65636 43877 Q1524
# 46587 43877 Q1524
# 61001 26971 Q483229
# 65959 47661 Q835662
# 19256 71190 Q1191195
# 44916 23792 Q22247780
# 44916 22324 Q22247780
# 23792 22324 Q22247780
# 89033 47950 Q1771020
# 93115 19917 Q16324495
# 99938 82715 Q174710
# 85223 33162 Q14212
# 00686 87412 Q1219561
# 66570 23208 Q1607
# 06474 31757 Q734427
# 80983 95092 Q9288
# 43672 70295 Q714891
# 92945 67184 Q995026
# 50290 37534 Q245126
# 82447 31377 Q13411156
# 94533 41242 Q113013063
# 50034 74885 Q101625
# 18121 24866 Q16225803
# 75658 02217 Q12722
# 21477 83758 Q27043871
# 21477 12433 Q27043871
# 83758 12433 Q27043871
# 30528 02523 Q212990
# 78145 95960 Q17393
# 26154 30031 Q158923
# 85702 07846 Q161775
# 85874 15960 Q257574
# 85284 55097 Q149990
# 71834 23132 Q23106
# 15828 11004 Q17487582
# 05548 11260 Q739302
# 20698 89092 Q47715
# 64182 37502 Q2684
# 31516 54741 Q214905
# 01088 53718 Q472741
# 54474 69133 Q178810
# 95737 76171 Q266963
# 92145 56284 Q987976
# 49095 52199 Q1025
# 49095 11724 Q1025
# 52199 11724 Q1025
# 52859 04389 Q15531382
# 27404 05733 Q841506
# 81036 37934 Q7989074
# 14457 20378 Q847587
# 61277 67731 Q5509914
# 02710 17396 Q21187575
# 89549 12726 Q186557
# 72517 32957 Q99
# 70142 67294 Q19900
# 72105 38373 Q179700
# 72105 75111 Q179700
# 38373 75111 Q179700
# 88331 07790 Q6735870
# 65111 01152 Q192816
# 74981 50507 Q1986
# 81956 46237 Q6317522
# 92024 71390 Q26988
# 78093 09084 Q1291181
# 17881 66405 Q106685
# 98039 44257 Q1030402
# 07291 52169 Q27139135
# 58159 59872 Q930729
# 37407 46535 Q5398426
# 37407 67692 Q5398426
# 46535 67692 Q5398426
# 55977 01099 Q432
# 55977 41856 Q432
# 01099 41856 Q432
# 35386 56237 Q15095148
# 48952 43348 Q18579
# 01691 74340 Q10082
# 86270 57982 Q165091
# 35736 89147 Q44559
# 62720 15838 Q23673
# 23796 08638 Q10279370
# 63526 98017 Q1340813
# 72222 04353 Q1008
# 72222 33767 Q1008
# 04353 33767 Q1008
# 36913 59878 Q304191
# 40444 43781 Q4200627
# 74722 61529 Q16024164
# 72803 94921 Q159260
# 96437 15458 Q3225114
# 45485 58845 Q545449
# 30072 44425 Q21199067
# 39034 45845 Q110918424
# 39286 63890 Q333515
# 58074 47469 Q18097
# 58074 81184 Q18097
# 47469 81184 Q18097
# 66614 94347 Q631045
# 29699 31138 Q7623378
# 47880 29525 Q16100
# 91400 97488 Q106615554
# 51104 24562 Q7275
# 61164 87401 Q1765460
# 21281 59086 Q157610
# 74152 57081 Q982503
# 02584 65774 Q1378024
# 73570 64484 Q714
# 66879 54543 Q3429410
# 96640 29449 Q1577033
# 99486 16822 Q223269
# 84009 86164 Q7374196
# 57944 90772 Q18708
# 16621 20295 Q522526
# 53344 20059 Q188779
# 25818 33270 Q309481
# 35549 01081 Q183127
# 89442 80353 Q217230
# 00676 57675 Q179789
# 38359 62973 Q14562306
# 38359 10989 Q14562306
# 62973 10989 Q14562306
# 90148 96849 Q1533
# 28395 80630 Q170513
# 50869 32134 Q3046
# 94062 91477 Q49757
# 89058 57037 Q38848
# 08003 48882 Q685884
# 68895 96824 Q35178
# 47615 93798 Q986329
# 57271 97493 Q815890
# 65644 74357 Q30525564
# 72157 43863 Q56739626
# 53404 45850 Q1016723
# 81949 50735 Q735
# 27476 38935 Q99298688
# 04483 37246 Q6926246
# 19540 27272 Q345702
# 07043 58259 Q133935
# 49933 73796 Q66774
# 73935 95410 Q4558480
# 27144 57790 Q50195
# 03665 80892 Q8016170
# 49892 07294 Q166
# 39474 23203 Q6157185
# 74849 15134 Q153006
# 05533 80399 Q205972
# 16720 62223 Q7094
# 72763 26438 Q222738
# 12417 23620 Q97990078
# 11394 05623 Q18662
# 12356 11035 Q6157
# 51643 99072 Q161116
# 99642 70254 Q50713
# 06360 27429 Q16210315
# 12831 81872 Q29999237
# 67814 03838 Q985022
# 53023 84905 Q1070
# 37685 50229 Q99288
# 73646 25806 Q223659
# 31572 46002 Q81779802
# 37100 72098 Q1594054
# 56567 69574 Q27786531
# 56567 89432 Q27786531
# 69574 89432 Q27786531
# 87134 29462 Q264206
# 07058 00964 Q669719
# 80074 75084 Q50315992
# 51707 04726 Q56760318
# 94912 44017 Q2074
# 32973 13963 Q2654
# 41789 20751 Q8828
# 58797 16466 Q894605
# 80274 93603 Q21067366
# 47713 40269 Q3361
# 06376 18519 Q424972
# 66593 05019 Q456327
# 01851 29969 Q7895319
# 23647 84951 Q165631
# 89533 48670 Q2402
# 65341 99081 Q191107
# 93110 68884 Q21899383
# 21997 88008 Q1506978
# 75634 87588 Q16069426
# 74534 97299 Q12156
# 77733 87923 Q15646788
# 75480 28462 Q2213452
# 55131 67839 Q835960
# 23804 18224 Q333424
# 30585 45311 Q25271
# 35843 47487 Q44727
# 71639 43404 Q132705
# 77315 12090 Q9083
# 77315 95780 Q9083
# 77315 46922 Q9083
# 12090 95780 Q9083
# 12090 46922 Q9083
# 95780 46922 Q9083
# 55649 23383 Q5547005
# 41461 05746 Q3076979
# 03494 68723 Q43689
# 01228 44181 Q2090893
# 00140 10985 Q1295201
# 02333 09892 Q22645
# 43792 01151 Q18200522
# 29122 72598 Q81882
# 59733 86711 Q818048
# 45577 81513 Q528042
# 32462 63647 Q129018
# 13768 15167 Q3866524
# 39460 84995 Q5090
# 98048 84173 Q495774
# 52319 81749 Q146342
# 13050 01162 Q16331
# 86457 19464 Q1640319
# 95074 72813 Q1034
# 37314 90803 Q1308
# 65350 30546 Q123977
# 33340 64273 Q55583861
# 26053 29648 Q8502
# 44173 55875 Q34647
# 12987 63713 Q6314039
# 39682 06629 Q7168
# 16231 59989 Q1020
# 16231 41773 Q1020
# 59989 41773 Q1020
# 97184 34607 Q1544011
# 42155 14744 Q33823
# 89013 90869 Q217102
# 59806 88905 Q504256
# 95189 37949 Q5253290
# 55794 61862 Q14907752
# 54870 87878 Q9089
# 25751 14854 Q28207111
# 24244 58081 Q3856
# 60882 98956 Q7082332
# 34457 69765 Q41083
# 29883 01592 Q207679
# 04842 94718 Q836836
# 57577 81850 Q653433
# 03110 53542 Q1408
# 60497 01101 Q771220
# 37236 75894 Q41217
# 04786 16082 Q21116733
# 82792 31582 Q4582333
# 64660 27760 Q523274
# 67568 40615 Q228
# 55000 51198 Q7169
# 90632 44829 Q1066487
# 76195 36123 Q79980
# 06696 63695 Q16733171
# 82888 64208 Q203174
# 32661 46510 Q622813
# 92333 62993 Q1535963
# 15522 85454 Q15681
# 69275 23105 Q9734
# 52056 17303 Q578904
# 73690 93034 Q35497
# 47899 51601 Q190583
# 03518 25208 Q262684
# 84532 22556 Q66601
# 20167 67407 Q575
# 15299 37023 Q911092
# 36325 42873 Q133266
# ✅ Saved 8816 pairs WITH QID to /hpctmp/e1351271/wkdbs/data/qid_pairs.csv

# %%
import os
import re
import csv

INPUT_DIR = "/hpctmp/e1351271/wkdbs/out/random_pairs_max_similarity_10k"
OUTPUT_CSV = "/hpctmp/e1351271/wkdbs/out/col_matcher_cosine_idf/col_matcher_sample_10k.csv"

# 正则表达式
pair_pattern = re.compile(r"Matched pair: \('(.*)',\s*'(.*)'\)")
similarity_pattern = re.compile(r"Max similarity:\s+([0-9.]+)")
runtime_pattern = re.compile(r"Runtime:\s+([0-9.]+)\s+seconds")
db_pattern = re.compile(r"(\d{5})\s+<-->\s+(\d{5})")

records = []

for fname in os.listdir(INPUT_DIR):
    if not fname.endswith(".txt"):
        continue
    fpath = os.path.join(INPUT_DIR, fname)
    with open(fpath, "r", encoding="utf-8") as f:
        lines = f.readlines()

    # 提取 db ids 从文件名或首行
    db_match = db_pattern.search(lines[0])
    if not db_match:
        print(f"⚠️ Failed to extract db pair from {fname}")
        continue
    db1, db2 = db_match.group(1), db_match.group(2)

    # 提取 matched pair
    pair_match = None
    for line in lines:
        if "Matched pair" in line:
            pair_match = pair_pattern.search(line)
            break
    if not pair_match:
        print(f"⚠️ No matched pair found in {fname}")
        continue
    col1, col2 = pair_match.group(1), pair_match.group(2)

    # 提取 similarity
    similarity = None
    for line in lines:
        sim_match = similarity_pattern.search(line)
        if sim_match:
            similarity = float(sim_match.group(1))
            break
    if similarity is None:
        print(f"⚠️ Similarity missing in {fname}")
        continue

    # 提取 runtime
    runtime = None
    for line in lines:
        run_match = runtime_pattern.search(line)
        if run_match:
            runtime = float(run_match.group(1))
            break
    if runtime is None:
        print(f"⚠️ Runtime missing in {fname}")
        continue

    records.append([db1, db2, col1, col2, similarity, runtime])

# 写入 CSV
os.makedirs(os.path.dirname(OUTPUT_CSV), exist_ok=True)
with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["db_1", "db_2", "column_1", "column_2", "similarity", "runtime_seconds"])
    writer.writerows(records)

print(f"✅ Converted {len(records)} files to: {OUTPUT_CSV}")
# Out:
# 📂 Processing /hpctmp/e1351271/wkdbs/out/qid_pairs_max_similarity
# ⚠️ No matched pair found in 85700_60209_Q83310_pair.txt
# ⚠️ No matched pair found in 20698_89092_Q47715_pair.txt
# ⚠️ No matched pair found in 58794_61614_Q212_pair.txt
# ⚠️ No matched pair found in 88736_09644_Q5287_pair.txt
# ⚠️ No matched pair found in 65468_09644_Q5287_pair.txt
# ⚠️ No matched pair found in 61614_84740_Q212_pair.txt
# ⚠️ No matched pair found in 50271_09644_Q5287_pair.txt
# ⚠️ No matched pair found in 97760_61614_Q212_pair.txt
# ⚠️ No matched pair found in 40067_30407_Q7108_pair.txt
# ✅ Saved 8795 rows to /hpctmp/e1351271/wkdbs/out/col_matcher_cosine_no_idf/col_matcher_qid.csv
#
# 📂 Processing /hpctmp/e1351271/wkdbs/out/sample_pairs_max_similarity
# ✅ Saved 0 rows to /hpctmp/e1351271/wkdbs/out/col_matcher_cosine_no_idf/col_matcher_sample_10k.csv
